# %% [markdown]
# Objective:
#
# We initially believed there is likely to be an association with deprivation levels and rates of injury. We will do this by comparing 1 month of NHS maternity dataset - trauma reported to the deprivation deciles at birth and observe if there is a positive correlation from there.
#
# After doing exploratory data analysis we found there was a weak negative correlation between deprivation levels and injury rates, finding richer areas were more likely to incur injuries while giving birth.
#
# Scope creep - From this the objective has changed, we will thoroughly analyse almost every element of the NHS maternity dataset to see if we can find what factors influence injury rates the most.

# %% [markdown]
# Accounting for misreporting:
#
# From previous analysis we are aware there is misreporting of trauma data, with some trusts reporting that they have no trauma in their maternity wards.
# There are other missing values and misreportings among the other elements of the dataset but it is not possible to filter this out unless analysing the data on a more granular scale. This scope creep will be avoided as otherwise the analysis will never finish and will likely result in the data being so incomplete nothing can be drawn from it.
#
# Due to the offical nature of the reporting it is highly unlikely trusts will over-report trauma.
#
# Update - we will only remove trusts that have trauma rates under 10% as there are only 3 clear cases of misreporting.
#
# These trusts are:
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST,
# ROYAL FREE LONDON NHS FOUNDATION TRUST,
# THE SHREWSBURY AND TELFORD HOSPITAL NHS TRUST

# %% [markdown]
# Results:
# Visualisations can be found at the bottom
# There is a large correlation between % of black mothers and emergency C sections
# There is a large correlation between deprivation and % of mothers that smoke
# There is a slight correlation between deprivation and emergency c sections

# %%
import pandas as pd
import glob
import numpy as np
from numpy.polynomial.polynomial import Polynomial
import os
from datetime import datetime
import bokeh
import pandas_bokeh
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, HoverTool, LabelSet
from bokeh.transform import cumsum
from bokeh.palettes import Category20c
from math import pi
from IPython.display import FileLink
from scipy.stats import t
from bokeh.plotting import figure, show, output_notebook
from bokeh.transform import dodge
from bokeh.models import ColumnDataSource, HoverTool

# %%
#Initalises our maternity dataset
pd.set_option('plotting.backend', 'pandas_bokeh')
output_notebook()
file_path = 'C:/NHS maternity data/2023/msds-apr2023-exp-data-final.csv'

df = pd.read_csv(file_path)
df.head()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ced84e8a-67c6-46b2-8f33-c64d316485b8">Loading BokehJS ...</span>
#     </div>
#   ReportingPeriodStartDate ReportingPeriodEndDate                Dimension  \
# 0               01/04/2023             30/04/2023    AgeAtBookingMotherAvg
# 1               01/04/2023             30/04/2023  AgeAtBookingMotherGroup
# 2               01/04/2023             30/04/2023  AgeAtBookingMotherGroup
# 3               01/04/2023             30/04/2023  AgeAtBookingMotherGroup
# 4               01/04/2023             30/04/2023  AgeAtBookingMotherGroup
#
#   Org_Level Org_Code        Org_Name   Measure            Count_Of  \
# 0  National      ALL  ALL SUBMITTERS       NaN  Average over women
# 1  National      ALL  ALL SUBMITTERS  20 to 24               Women
# 2  National      ALL  ALL SUBMITTERS  25 to 29               Women
# 3  National      ALL  ALL SUBMITTERS  30 to 34               Women
# 4  National      ALL  ALL SUBMITTERS  35 to 39               Women
#
#    Final_value
# 0           31
# 1         6525
# 2        13710
# 3        17640
# 4         9895

# %%
def pearson_correlation_debug(x, y):
    n = len(x)
    mean_x = sum(x) / n
    mean_y = sum(y) / n
    covariance = sum((x.iloc[i] - mean_x) * (y.iloc[i] - mean_y) for i in range(n))
    std_x = (sum((x.iloc[i] - mean_x) ** 2 for i in range(n)) ** 0.5)
    std_y = (sum((y.iloc[i] - mean_y) ** 2 for i in range(n)) ** 0.5)
    if std_x == 0 or std_y == 0:
        return float('nan')
    r = covariance / (std_x * std_y)
    return r

# %%
def remove_outliers(df):
    
    df_clean = df.copy()

    for col in df.columns:
        if df[col].dtype.kind in 'bifc':  
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            df_clean = df_clean[(df_clean[col] >= lower_bound) & (df_clean[col] <= upper_bound)]
    
    return df_clean

# %%
def pearson_correlation_with_pvalue_debug(x, y):
    n = len(x)
    r = pearson_correlation_debug(x, y)
    if pd.isna(r):  # Check if r is NaN
        print("Pearson correlation coefficient is NaN.")
        return r, float('nan')
    
    # Handle the case where r is exactly 1 or -1
    if r == 1 or r == -1:
        print("Pearson correlation coefficient is exactly 1 or -1.")
        return r, 0.0  # P-value is 0 because the correlation is perfect
    
    # t-statistic
    t_stat = r * ((n - 2) / (1 - r ** 2)) ** 0.5
    p_value = 2 * t.sf(abs(t_stat), df=n - 2)
    if p_value < 1e-10:
        p_value = "< 1e-10"  
    
    return r, p_value

# %%
dftrusts = df[df['Org_Name'].str.contains('trust', case=False, na=False)]

# %%
unwanted_measures = [
    "Missing Value / Value outside reporting parameters",
    "Pseudo postcode recorded (includes no fixed abode or resident overseas)",
    "Resident Elsewhere in UK, Channel Islands or Isle of Man"
]
dftrusts.head(100)
# Out:
#       ReportingPeriodStartDate ReportingPeriodEndDate  \
# 33452               01/04/2023             30/04/2023
# 33453               01/04/2023             30/04/2023
# 33454               01/04/2023             30/04/2023
# 33455               01/04/2023             30/04/2023
# 33456               01/04/2023             30/04/2023
# ...                        ...                    ...
# 33547               01/04/2023             30/04/2023
# 33548               01/04/2023             30/04/2023
# 33549               01/04/2023             30/04/2023
# 33550               01/04/2023             30/04/2023
# 33551               01/04/2023             30/04/2023
#
#                        Dimension Org_Level Org_Code  \
# 33452      AgeAtBookingMotherAvg  Provider      R0A
# 33453    AgeAtBookingMotherGroup  Provider      R0A
# 33454    AgeAtBookingMotherGroup  Provider      R0A
# 33455    AgeAtBookingMotherGroup  Provider      R0A
# 33456    AgeAtBookingMotherGroup  Provider      R0A
# ...                          ...       ...      ...
# 33547  SmokingStatusGroupBooking  Provider      R0A
# 33548  SmokingStatusGroupBooking  Provider      R0A
# 33549                TotalBabies  Provider      R0A
# 33550              TotalBookings  Provider      R0A
# 33551            TotalDeliveries  Provider      R0A
#
#                                          Org_Name                 Measure  \
# 33452  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                     NaN
# 33453  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                20 to 24
# 33454  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                25 to 29
# 33455  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                30 to 34
# 33456  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                35 to 39
# ...                                           ...                     ...
# 33547  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST  Non-Smoker / Ex-Smoker
# 33548  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                  Smoker
# 33549  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                     NaN
# 33550  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                     NaN
# 33551  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST                     NaN
#
#                  Count_Of  Final_value
# 33452  Average over women           31
# 33453               Women          180
# 33454               Women          400
# 33455               Women          525
# 33456               Women          285
# ...                   ...          ...
# 33547               Women         1095
# 33548               Women           95
# 33549              Babies         1210
# 33550               Women         1525
# 33551               Women         1195
#
# [100 rows x 9 columns]

# %%
dftrusts = dftrusts[~dftrusts['Measure'].isin(unwanted_measures)]
dftrusts.head(100)
# Out:
#       ReportingPeriodStartDate ReportingPeriodEndDate  \
# 33452               01/04/2023             30/04/2023
# 33453               01/04/2023             30/04/2023
# 33454               01/04/2023             30/04/2023
# 33455               01/04/2023             30/04/2023
# 33456               01/04/2023             30/04/2023
# ...                        ...                    ...
# 33562               01/04/2023             30/04/2023
# 33564               01/04/2023             30/04/2023
# 33565               01/04/2023             30/04/2023
# 33566               01/04/2023             30/04/2023
# 33567               01/04/2023             30/04/2023
#
#                            Dimension Org_Level Org_Code  \
# 33452          AgeAtBookingMotherAvg  Provider      R0A
# 33453        AgeAtBookingMotherGroup  Provider      R0A
# 33454        AgeAtBookingMotherGroup  Provider      R0A
# 33455        AgeAtBookingMotherGroup  Provider      R0A
# 33456        AgeAtBookingMotherGroup  Provider      R0A
# ...                              ...       ...      ...
# 33562          ApgarScore5TermGroup7  Provider      R0B
# 33564  BabyFirstFeedBreastMilkStatus  Provider      R0B
# 33565  BabyFirstFeedBreastMilkStatus  Provider      R0B
# 33566           BirthweightTermGroup  Provider      R0B
# 33567           BirthweightTermGroup  Provider      R0B
#
#                                                 Org_Name  \
# 33452         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33453         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33454         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33455         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33456         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# ...                                                  ...
# 33562  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33564  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33565  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33566  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33567  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
#
#                              Measure            Count_Of  Final_value
# 33452                            NaN  Average over women           31
# 33453                       20 to 24               Women          180
# 33454                       25 to 29               Women          400
# 33455                       30 to 34               Women          525
# 33456                       35 to 39               Women          285
# ...                              ...                 ...          ...
# 33562                        7 to 10              Babies          240
# 33564  Maternal or Donor Breast Milk              Babies          135
# 33565                Not Breast Milk              Babies          135
# 33566                 2000g to 2499g              Babies           10
# 33567                 2500g to 2999g              Babies           40
#
# [100 rows x 9 columns]

# %%
dftrusts.loc[dftrusts['Dimension'] == 'DeprivationDecileAtBooking', 'Measure'] = (
    dftrusts.loc[dftrusts['Dimension'] == 'DeprivationDecileAtBooking', 'Measure']
    .apply(lambda x: x[:2] if len(x) > 2 else x) 
)
dftrusts.loc[(dftrusts['Dimension'] == 'DeprivationDecileAtBooking') & (dftrusts['Measure'] == '01'), 'Measure'] = '1'

dftrusts.head(100)
# Out:
#       ReportingPeriodStartDate ReportingPeriodEndDate  \
# 33452               01/04/2023             30/04/2023
# 33453               01/04/2023             30/04/2023
# 33454               01/04/2023             30/04/2023
# 33455               01/04/2023             30/04/2023
# 33456               01/04/2023             30/04/2023
# ...                        ...                    ...
# 33562               01/04/2023             30/04/2023
# 33564               01/04/2023             30/04/2023
# 33565               01/04/2023             30/04/2023
# 33566               01/04/2023             30/04/2023
# 33567               01/04/2023             30/04/2023
#
#                            Dimension Org_Level Org_Code  \
# 33452          AgeAtBookingMotherAvg  Provider      R0A
# 33453        AgeAtBookingMotherGroup  Provider      R0A
# 33454        AgeAtBookingMotherGroup  Provider      R0A
# 33455        AgeAtBookingMotherGroup  Provider      R0A
# 33456        AgeAtBookingMotherGroup  Provider      R0A
# ...                              ...       ...      ...
# 33562          ApgarScore5TermGroup7  Provider      R0B
# 33564  BabyFirstFeedBreastMilkStatus  Provider      R0B
# 33565  BabyFirstFeedBreastMilkStatus  Provider      R0B
# 33566           BirthweightTermGroup  Provider      R0B
# 33567           BirthweightTermGroup  Provider      R0B
#
#                                                 Org_Name  \
# 33452         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33453         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33454         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33455         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33456         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# ...                                                  ...
# 33562  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33564  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33565  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33566  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33567  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
#
#                              Measure            Count_Of  Final_value
# 33452                            NaN  Average over women           31
# 33453                       20 to 24               Women          180
# 33454                       25 to 29               Women          400
# 33455                       30 to 34               Women          525
# 33456                       35 to 39               Women          285
# ...                              ...                 ...          ...
# 33562                        7 to 10              Babies          240
# 33564  Maternal or Donor Breast Milk              Babies          135
# 33565                Not Breast Milk              Babies          135
# 33566                 2000g to 2499g              Babies           10
# 33567                 2500g to 2999g              Babies           40
#
# [100 rows x 9 columns]

# %%
dftrusts.loc[dftrusts['Dimension'] == 'DeprivationDecileAtBooking', 'Measure'] = (
    dftrusts.loc[dftrusts['Dimension'] == 'DeprivationDecileAtBooking', 'Measure']
    .astype(int)  
)
dftrusts.head(400)
# Out:
#       ReportingPeriodStartDate ReportingPeriodEndDate  \
# 33452               01/04/2023             30/04/2023
# 33453               01/04/2023             30/04/2023
# 33454               01/04/2023             30/04/2023
# 33455               01/04/2023             30/04/2023
# 33456               01/04/2023             30/04/2023
# ...                        ...                    ...
# 33893               01/04/2023             30/04/2023
# 33894               01/04/2023             30/04/2023
# 33895               01/04/2023             30/04/2023
# 33896               01/04/2023             30/04/2023
# 33897               01/04/2023             30/04/2023
#
#                         Dimension Org_Level Org_Code  \
# 33452       AgeAtBookingMotherAvg  Provider      R0A
# 33453     AgeAtBookingMotherGroup  Provider      R0A
# 33454     AgeAtBookingMotherGroup  Provider      R0A
# 33455     AgeAtBookingMotherGroup  Provider      R0A
# 33456     AgeAtBookingMotherGroup  Provider      R0A
# ...                           ...       ...      ...
# 33893  DeprivationDecileAtBooking  Provider      R1H
# 33894  DeprivationDecileAtBooking  Provider      R1H
# 33895  DeprivationDecileAtBooking  Provider      R1H
# 33896  DeprivationDecileAtBooking  Provider      R1H
# 33897  DeprivationDecileAtBooking  Provider      R1H
#
#                                          Org_Name   Measure  \
# 33452  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       NaN
# 33453  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST  20 to 24
# 33454  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST  25 to 29
# 33455  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST  30 to 34
# 33456  MANCHESTER UNIVERSITY NHS FOUNDATION TRUST  35 to 39
# ...                                           ...       ...
# 33893                      BARTS HEALTH NHS TRUST         2
# 33894                      BARTS HEALTH NHS TRUST         3
# 33895                      BARTS HEALTH NHS TRUST         4
# 33896                      BARTS HEALTH NHS TRUST         5
# 33897                      BARTS HEALTH NHS TRUST         6
#
#                  Count_Of  Final_value
# 33452  Average over women           31
# 33453               Women          180
# 33454               Women          400
# 33455               Women          525
# 33456               Women          285
# ...                   ...          ...
# 33893               Women          370
# 33894               Women          370
# 33895               Women          185
# 33896               Women           75
# 33897               Women           55
#
# [400 rows x 9 columns]

# %%
dfdeprivation = dftrusts[dftrusts['Dimension'] == 'DeprivationDecileAtBooking']

dfdeprivation.head(100)
# Out:
#       ReportingPeriodStartDate ReportingPeriodEndDate  \
# 33485               01/04/2023             30/04/2023
# 33486               01/04/2023             30/04/2023
# 33487               01/04/2023             30/04/2023
# 33488               01/04/2023             30/04/2023
# 33489               01/04/2023             30/04/2023
# ...                        ...                    ...
# 34428               01/04/2023             30/04/2023
# 34429               01/04/2023             30/04/2023
# 34532               01/04/2023             30/04/2023
# 34533               01/04/2023             30/04/2023
# 34534               01/04/2023             30/04/2023
#
#                         Dimension Org_Level Org_Code  \
# 33485  DeprivationDecileAtBooking  Provider      R0A
# 33486  DeprivationDecileAtBooking  Provider      R0A
# 33487  DeprivationDecileAtBooking  Provider      R0A
# 33488  DeprivationDecileAtBooking  Provider      R0A
# 33489  DeprivationDecileAtBooking  Provider      R0A
# ...                           ...       ...      ...
# 34428  DeprivationDecileAtBooking  Provider      RAE
# 34429  DeprivationDecileAtBooking  Provider      RAE
# 34532  DeprivationDecileAtBooking  Provider      RAJ
# 34533  DeprivationDecileAtBooking  Provider      RAJ
# 34534  DeprivationDecileAtBooking  Provider      RAJ
#
#                                                Org_Name Measure Count_Of  \
# 33485        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       2    Women
# 33486        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       3    Women
# 33487        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       4    Women
# 33488        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       5    Women
# 33489        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       6    Women
# ...                                                 ...     ...      ...
# 34428  BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST       1    Women
# 34429  BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST      10    Women
# 34532          MID AND SOUTH ESSEX NHS FOUNDATION TRUST       2    Women
# 34533          MID AND SOUTH ESSEX NHS FOUNDATION TRUST       3    Women
# 34534          MID AND SOUTH ESSEX NHS FOUNDATION TRUST       4    Women
#
#        Final_value
# 33485          260
# 33486          180
# 33487          150
# 33488          110
# 33489           90
# ...            ...
# 34428          260
# 34429            5
# 34532           80
# 34533          120
# 34534          130
#
# [100 rows x 9 columns]

# %%
dfdeprivation = dfdeprivation.sort_values(by=['Org_Code', 'Measure'])

dfdeprivation.head(100)
# Out:
#       ReportingPeriodStartDate ReportingPeriodEndDate  \
# 33493               01/04/2023             30/04/2023
# 33485               01/04/2023             30/04/2023
# 33486               01/04/2023             30/04/2023
# 33487               01/04/2023             30/04/2023
# 33488               01/04/2023             30/04/2023
# ...                        ...                    ...
# 34427               01/04/2023             30/04/2023
# 34429               01/04/2023             30/04/2023
# 34540               01/04/2023             30/04/2023
# 34532               01/04/2023             30/04/2023
# 34533               01/04/2023             30/04/2023
#
#                         Dimension Org_Level Org_Code  \
# 33493  DeprivationDecileAtBooking  Provider      R0A
# 33485  DeprivationDecileAtBooking  Provider      R0A
# 33486  DeprivationDecileAtBooking  Provider      R0A
# 33487  DeprivationDecileAtBooking  Provider      R0A
# 33488  DeprivationDecileAtBooking  Provider      R0A
# ...                           ...       ...      ...
# 34427  DeprivationDecileAtBooking  Provider      RAE
# 34429  DeprivationDecileAtBooking  Provider      RAE
# 34540  DeprivationDecileAtBooking  Provider      RAJ
# 34532  DeprivationDecileAtBooking  Provider      RAJ
# 34533  DeprivationDecileAtBooking  Provider      RAJ
#
#                                                Org_Name Measure Count_Of  \
# 33493        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       1    Women
# 33485        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       2    Women
# 33486        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       3    Women
# 33487        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       4    Women
# 33488        MANCHESTER UNIVERSITY NHS FOUNDATION TRUST       5    Women
# ...                                                 ...     ...      ...
# 34427  BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST       9    Women
# 34429  BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST      10    Women
# 34540          MID AND SOUTH ESSEX NHS FOUNDATION TRUST       1    Women
# 34532          MID AND SOUTH ESSEX NHS FOUNDATION TRUST       2    Women
# 34533          MID AND SOUTH ESSEX NHS FOUNDATION TRUST       3    Women
#
#        Final_value
# 33493          445
# 33485          260
# 33486          180
# 33487          150
# 33488          110
# ...            ...
# 34427            5
# 34429            5
# 34540           65
# 34532           80
# 34533          120
#
# [100 rows x 9 columns]

# %% [markdown]
# To calculate our stats, we will take each measure * final value, then divide this by the total final value. This will give us our 'average deprivation' for each trust

# %%
dfdeprivation['Total Deprivation'] = dfdeprivation['Measure'] * dfdeprivation['Final_value']
total_deprivation_by_org = dfdeprivation.groupby('Org_Name')['Total Deprivation'].sum()

total_value_by_org = dfdeprivation.groupby('Org_Name')['Final_value'].sum()

total_deprivation_by_org
# Out:
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                      950
# AIREDALE NHS TRUST                                                 730
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION TRUST             1985
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSPITALS NHS TRUST    2790
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                             875
#                                                                   ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDATION TRUST          1000
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                          2585
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                 790
# WYE VALLEY NHS TRUST                                               830
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOUNDATION TRUST       225
# Name: Total Deprivation, Length: 124, dtype: object

# %%
actual_deprivation = total_deprivation_by_org / total_value_by_org
actual_deprivation_df = actual_deprivation.reset_index()
actual_deprivation_df.columns = ['Org_Name', 'Deprivation']
actual_deprivation_df.head(100)
# Out:
#                                              Org_Name Deprivation
# 0                       AIREDALE NHS FOUNDATION TRUST    5.277778
# 1                                  AIREDALE NHS TRUST    5.214286
# 2   ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...    7.218182
# 3   BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...    4.292308
# 4              BARNSLEY HOSPITAL NHS FOUNDATION TRUST    3.723404
# ..                                                ...         ...
# 95          THE PRINCESS ALEXANDRA HOSPITAL NHS TRUST    6.424242
# 96  THE QUEEN ELIZABETH HOSPITAL, KING'S LYNN, NHS...    4.103448
# 97                 THE ROTHERHAM NHS FOUNDATION TRUST    3.744186
# 98                  THE ROYAL WOLVERHAMPTON NHS TRUST    3.613208
# 99      THE SHREWSBURY AND TELFORD HOSPITAL NHS TRUST    5.069767
#
# [100 rows x 2 columns]

# %% [markdown]
# We now have our deprivation stats. Now we will Calculate our rates of trauma as a percentage. We will then analyse for an association between the trauma rates and our deprivation rates. Based on this we may analyse for associations between injury rates and other factors.

# %%
dftrauma = dftrusts[dftrusts['Dimension'] == 'GenitalTractTraumaticLesionGroup']
dftrauma = dftrauma[['Dimension', 'Org_Name', 'Measure', 'Final_value']]
dftrauma.head(100)
# Out:
#                               Dimension  \
# 33511  GenitalTractTraumaticLesionGroup
# 33512  GenitalTractTraumaticLesionGroup
# 33617  GenitalTractTraumaticLesionGroup
# 33618  GenitalTractTraumaticLesionGroup
# 33724  GenitalTractTraumaticLesionGroup
# ...                                 ...
# 38471  GenitalTractTraumaticLesionGroup
# 38472  GenitalTractTraumaticLesionGroup
# 38582  GenitalTractTraumaticLesionGroup
# 38583  GenitalTractTraumaticLesionGroup
# 38681  GenitalTractTraumaticLesionGroup
#
#                                                 Org_Name  \
# 33511         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33512         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33617  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33618  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33724   UNIVERSITY HOSPITALS DORSET NHS FOUNDATION TRUST
# ...                                                  ...
# 38471  ST GEORGE'S UNIVERSITY HOSPITALS NHS FOUNDATIO...
# 38472  ST GEORGE'S UNIVERSITY HOSPITALS NHS FOUNDATIO...
# 38582  SOUTH WARWICKSHIRE UNIVERSITY NHS FOUNDATION T...
# 38583  SOUTH WARWICKSHIRE UNIVERSITY NHS FOUNDATION T...
# 38681   UNIVERSITY HOSPITALS OF NORTH MIDLANDS NHS TRUST
#
#                              Measure  Final_value
# 33511  At least one traumatic lesion          255
# 33512   No traumatic lesion reported          390
# 33617  At least one traumatic lesion          170
# 33618   No traumatic lesion reported           30
# 33724  At least one traumatic lesion          110
# ...                              ...          ...
# 38471  At least one traumatic lesion          110
# 38472   No traumatic lesion reported           90
# 38582  At least one traumatic lesion          115
# 38583   No traumatic lesion reported           30
# 38681  At least one traumatic lesion          130
#
# [100 rows x 4 columns]

# %%
dftrauma2 = dftrauma.groupby(['Org_Name', 'Measure'])['Final_value'].sum().unstack()

# Calculate total Final_value for each Org_Name
dftrauma2['Total'] = dftrauma2.sum(axis=1)
# Calculate the trauma percentage
dftrauma2['Trauma Percentage'] = (dftrauma2['At least one traumatic lesion'] / dftrauma2['Total']) * 100
columns = dftrauma2.columns.tolist()
dftrauma2.columns = columns

dftrauma2.head(200)
# Out:
#                                                     At least one traumatic lesion  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                20.0
# AIREDALE NHS TRUST                                                           20.0
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                           80.0
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                          170.0
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                       85.0
# ...                                                                           ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                           75.0
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                    155.0
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                           30.0
# WYE VALLEY NHS TRUST                                                         45.0
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                            5.0
#
#                                                     No traumatic lesion reported  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                               60.0
# AIREDALE NHS TRUST                                                          55.0
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                          35.0
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                         140.0
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                      50.0
# ...                                                                          ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                          60.0
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                    70.0
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                          25.0
# WYE VALLEY NHS TRUST                                                        15.0
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                         170.0
#
#                                                     Total  Trauma Percentage
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                        80.0          25.000000
# AIREDALE NHS TRUST                                   75.0          26.666667
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...  115.0          69.565217
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...  310.0          54.838710
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST              135.0          62.962963
# ...                                                   ...                ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...  135.0          55.555556
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST            225.0          68.888889
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST   55.0          54.545455
# WYE VALLEY NHS TRUST                                 60.0          75.000000
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...  175.0           2.857143
#
# [123 rows x 4 columns]

# %% [markdown]
# Here we find an example of misreporting. If you look in the dataframe above and sort by trauma percentage ascending you'll find Imperial College Healthcare, Royal Free London NHS foundation trust and Shrewsbury and Telford Hospital report trauma at ridiculously low rates. This data is certainly incorrect. For the others it may be possible that they have such low injury rates as they have such low numbers in their maternity suite.

# %%
print("Index:", dftrauma2.index.names)
print("Columns:", dftrauma2.columns)
# Out:
# Index: ['Org_Name']
# Columns: Index(['At least one traumatic lesion', 'No traumatic lesion reported',
#        'Total', 'Trauma Percentage'],
#       dtype='object')

# %%
dftrauma2.reset_index(inplace=True)
print(dftrauma2.columns)

final_df = actual_deprivation_df.merge(dftrauma2[['Org_Name', 'Trauma Percentage']], on='Org_Name', how='left')
print(final_df.head())
# Out:
# Index(['Org_Name', 'At least one traumatic lesion',
#        'No traumatic lesion reported', 'Total', 'Trauma Percentage'],
#       dtype='object')
#                                             Org_Name Deprivation  \
# 0                      AIREDALE NHS FOUNDATION TRUST    5.277778
# 1                                 AIREDALE NHS TRUST    5.214286
# 2  ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...    7.218182
# 3  BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...    4.292308
# 4             BARNSLEY HOSPITAL NHS FOUNDATION TRUST    3.723404
#
#    Trauma Percentage
# 0          25.000000
# 1          26.666667
# 2          69.565217
# 3          54.838710
# 4          62.962963

# %%
final_df.head(100)
# Out:
#                                              Org_Name Deprivation  \
# 0                       AIREDALE NHS FOUNDATION TRUST    5.277778
# 1                                  AIREDALE NHS TRUST    5.214286
# 2   ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...    7.218182
# 3   BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...    4.292308
# 4              BARNSLEY HOSPITAL NHS FOUNDATION TRUST    3.723404
# ..                                                ...         ...
# 95          THE PRINCESS ALEXANDRA HOSPITAL NHS TRUST    6.424242
# 96  THE QUEEN ELIZABETH HOSPITAL, KING'S LYNN, NHS...    4.103448
# 97                 THE ROTHERHAM NHS FOUNDATION TRUST    3.744186
# 98                  THE ROYAL WOLVERHAMPTON NHS TRUST    3.613208
# 99      THE SHREWSBURY AND TELFORD HOSPITAL NHS TRUST    5.069767
#
#     Trauma Percentage
# 0           25.000000
# 1           26.666667
# 2           69.565217
# 3           54.838710
# 4           62.962963
# ..                ...
# 95          61.538462
# 96          75.000000
# 97          75.000000
# 98          69.767442
# 99           8.823529
#
# [100 rows x 3 columns]

# %%
final_df = final_df[final_df['Trauma Percentage'] >= 27]

# %% [markdown]
# The code above drops the data for:
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST           2.3%
# ROYAL FREE LONDON NHS FOUNDATION TRUST          3.07%
# THE SHREWSBURY AND TELFORD HOSPITAL NHS TRUST   8.52%
# SHEFFIELD TEACHING HOSPITALS NHS FOUNDATION TRUST 24% (Very round number?)
# AIREDALE NHS FOUNDATION TRUST   25%
# AIREDALE NHS TRUST  26.66%
# This is due to the exceedingly low rates of reported trauma

# %%
#This ruins the correlation code for some reason
# Calculate deciles for trauma percentage
#final_df['Decile'] = pd.qcut(final_df['Trauma Percentage'], 10, labels=False) + 1  # +1 to make deciles start from 1



#final_df['Deprivation'] = pd.to_numeric(final_df['Deprivation'], errors='coerce')
#final_df['Trauma Percentage'] = pd.to_numeric(final_df['Trauma Percentage'], errors='coerce')
#print(final_df['Deprivation'].dtype)
#print(final_df['Trauma Percentage'].dtype)
#final_df.head(100)

# %%
final_df = final_df.dropna(subset=['Trauma Percentage'])
x = final_df['Deprivation']
y = final_df['Trauma Percentage']

r, p_value = pearson_correlation_with_pvalue_debug(x, y)
print("Pearson correlation coefficient:", r)
print("P-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.14507588492112683
# P-value: 0.12187142462818243

# %%
def calculate_percentage(part, total):
    if total == 0:
        return None
    percentage = (part / total) * 100
    return percentage

# %% [markdown]
# As a higher number in deprivation means an area is less deprived, this is interesting. Lets invert our deprivation numbers.

# %%
final_df['Inverted Deprivation'] = final_df['Deprivation'].max() - final_df['Deprivation']

# Calculate the Pearson correlation with the inverted values
x = final_df['Inverted Deprivation']
y = final_df['Trauma Percentage']

r, p_value = pearson_correlation_with_pvalue_debug(x, y)
print("Pearson correlation coefficient (with inverted deprivation):", r)
print("P-value:", p_value)
# Out:
# Pearson correlation coefficient (with inverted deprivation): -0.14507588492112675
# P-value: 0.12187142462818258

# %% [markdown]
# Unfortunately as there is clearly an association now we must find out why. We hypothesise that birth weights and age of mother at birth could have a stronger correlation to trauma, and that in richer areas mothers give birth later (potentially to larger babies?).

# %%
df_age_at_booking = dftrusts[dftrusts['Dimension'] == 'AgeAtBookingMotherAvg']
df_age_at_booking = df_age_at_booking[['Org_Name', 'Dimension', 'Final_value']]
print(df_age_at_booking.head())
# Out:
#                                                 Org_Name  \
# 33452         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33552  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33659   UNIVERSITY HOSPITALS DORSET NHS FOUNDATION TRUST
# 33768                            ISLE OF WIGHT NHS TRUST
# 33860                             BARTS HEALTH NHS TRUST
#
#                    Dimension  Final_value
# 33452  AgeAtBookingMotherAvg           31
# 33552  AgeAtBookingMotherAvg           29
# 33659  AgeAtBookingMotherAvg           31
# 33768  AgeAtBookingMotherAvg           29
# 33860  AgeAtBookingMotherAvg           30

# %%
final_df_with_age = final_df.merge(df_age_at_booking[['Org_Name', 'Final_value']], on='Org_Name', how='left')


final_df_with_age.rename(columns={'Final_value': 'Avg age'}, inplace=True)

final_df_with_age.head()
# Out:
#                                             Org_Name Deprivation  \
# 0  ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...    7.218182
# 1  BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...    4.292308
# 2             BARNSLEY HOSPITAL NHS FOUNDATION TRUST    3.723404
# 3                             BARTS HEALTH NHS TRUST     3.22619
# 4        BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST         5.4
#
#    Trauma Percentage Inverted Deprivation  Avg age
# 0          69.565217             0.830999       31
# 1          54.838710             3.756873       30
# 2          62.962963             4.325776       29
# 3          36.434109              4.82299       30
# 4          77.586207              2.64918       31

# %%
x = final_df_with_age['Avg age']
y = final_df_with_age['Trauma Percentage']
r, p_value = pearson_correlation_with_pvalue_debug(x, y)
print("Pearson correlation coefficient:", r)
print("P-value:", p_value)
# Out:
# Pearson correlation coefficient: -0.01382782345201866
# P-value: 0.8828759849606236

# %% [markdown]
# There is a very small relation between age and trauma rates. It is not statistically significant enough to matter. However this seems to show that injury rates go down as age goes up? There could be a miscalculation in my pearson coefficient.

# %%
x = final_df_with_age['Avg age']
y = final_df_with_age['Deprivation']
r, p_value = pearson_correlation_with_pvalue_debug(x, y)
print("Pearson correlation coefficient:", r)
print("P-value:", p_value)
# Out:
# Pearson correlation coefficient: 0.5633596324930059
# P-value: < 1e-10

# %% [markdown]
# The P value is ridiculous but there is likely to be a correlation between deprivation and age.

# %%
df_smoking_status = dftrusts[dftrusts['Dimension'] == 'SmokingStatusGroupBooking']
df_smoking_status = df_smoking_status[['Org_Name', 'Dimension', 'Measure', 'Final_value']]
df_smoking_status.head()
# Out:
#                                                 Org_Name  \
# 33547         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33548         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33654  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33655  SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 33763   UNIVERSITY HOSPITALS DORSET NHS FOUNDATION TRUST
#
#                        Dimension                 Measure  Final_value
# 33547  SmokingStatusGroupBooking  Non-Smoker / Ex-Smoker         1095
# 33548  SmokingStatusGroupBooking                  Smoker           95
# 33654  SmokingStatusGroupBooking  Non-Smoker / Ex-Smoker          385
# 33655  SmokingStatusGroupBooking                  Smoker           65
# 33763  SmokingStatusGroupBooking  Non-Smoker / Ex-Smoker          330

# %%
df_smokers = df_smoking_status[df_smoking_status['Measure'] == 'Smoker']
total_final_values = df_smoking_status.groupby('Org_Name')['Final_value'].sum().reset_index()
df_smokers = df_smokers.merge(total_final_values, on='Org_Name', suffixes=('', '_Total'))
df_smokers['Smoker_Percentage'] = (df_smokers['Final_value'] / df_smokers['Final_value_Total']) * 100
df_smokers = df_smokers[['Org_Name', 'Smoker_Percentage']]
df_smokers.head(200)
# Out:
#                                               Org_Name  Smoker_Percentage
# 0           MANCHESTER UNIVERSITY NHS FOUNDATION TRUST           7.983193
# 1    SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...          14.444444
# 2     UNIVERSITY HOSPITALS DORSET NHS FOUNDATION TRUST           9.589041
# 3                              ISLE OF WIGHT NHS TRUST          18.750000
# 4                               BARTS HEALTH NHS TRUST           3.930131
# ..                                                 ...                ...
# 116              IMPERIAL COLLEGE HEALTHCARE NHS TRUST           4.081633
# 117   UNIVERSITY HOSPITALS SUSSEX NHS FOUNDATION TRUST           6.569343
# 118                                 AIREDALE NHS TRUST          11.764706
# 119  NOTTINGHAM UNIVERSITY HOSPITALS NHS TRUST - CI...          14.285714
# 120  NOTTINGHAM UNIVERSITY HOSPITALS NHS TRUST - QU...           9.090909
#
# [121 rows x 2 columns]

# %% [markdown]
# Let's check for smoking and deprivation, not sure what's going on with chelsea and westminster if you look at the above. 88% smokers in the maternity unit? Nuts. I've just realised I should've made a percentage function, I don't want to rewrite my code so I will write the function below and use it from here on but I will not rewrite previous percentage calculations.

# %%
final_df_with_smokers = final_df_with_age.merge(df_smokers, on='Org_Name', how='left')
final_df_with_smokers.head(200)
# Out:
#                                               Org_Name Deprivation  \
# 0    ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...    7.218182
# 1    BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...    4.292308
# 2               BARNSLEY HOSPITAL NHS FOUNDATION TRUST    3.723404
# 3                               BARTS HEALTH NHS TRUST     3.22619
# 4          BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST         5.4
# ..                                                 ...         ...
# 111                       WHITTINGTON HEALTH NHS TRUST    4.114754
# 112  WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...    4.166667
# 113           WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST    5.744444
# 114  WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION T...    4.514286
# 115                               WYE VALLEY NHS TRUST    5.354839
#
#      Trauma Percentage Inverted Deprivation  Avg age  Smoker_Percentage
# 0            69.565217             0.830999       31           9.433962
# 1            54.838710             3.756873       30           5.384615
# 2            62.962963             4.325776       29          14.893617
# 3            36.434109              4.82299       30           3.930131
# 4            77.586207              2.64918       31           7.368421
# ..                 ...                  ...      ...                ...
# 111          55.555556             3.934426       32           6.451613
# 112          55.555556             3.882514       29          10.000000
# 113          68.888889             2.304736       30          13.483146
# 114          54.545455             3.534895       29           8.571429
# 115          75.000000             2.694342       30          10.344828
#
# [116 rows x 6 columns]

# %% [markdown]
# As we have nan values we will drop these and print which trusts have been dropped

# %%
df_csf = dftrusts[dftrusts['Dimension'] == 'ComplexSocialFactorsInd']
df_csf_grouped = df_csf.groupby(['Org_Name', 'Measure'])['Final_value'].sum().unstack()
df_csf_grouped['Total'] = df_csf_grouped['N'] + df_csf_grouped['Y'] + df_csf_grouped['Missing Value']
df_csf_grouped['Missing_Percentage'] = df_csf_grouped.apply(lambda row: calculate_percentage(row['Missing Value'], row['Total']), axis=1)
df_csf_grouped['csfpercent'] = df_csf_grouped.apply(lambda row: calculate_percentage(row['Y'], row['N']), axis=1)
df_csf_grouped.loc['Missing_Percentage'] = df_csf_grouped['Missing_Percentage']
df_csf_grouped.reset_index(inplace=True)
df_csf_grouped = df_csf_grouped[['Org_Name', 'csfpercent', 'Missing_Percentage']]
df_csf_grouped.head(110)
# Out:
# Measure                                           Org_Name  csfpercent  \
# 0                            AIREDALE NHS FOUNDATION TRUST    5.714286
# 1                                       AIREDALE NHS TRUST    3.846154
# 2        ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...   14.583333
# 3        BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...   20.370370
# 4                   BARNSLEY HOSPITAL NHS FOUNDATION TRUST   11.627907
# ..                                                     ...         ...
# 105      UNIVERSITY HOSPITALS BRISTOL AND WESTON NHS FO...    9.677419
# 106      UNIVERSITY HOSPITALS COVENTRY AND WARWICKSHIRE...   32.558140
# 107       UNIVERSITY HOSPITALS DORSET NHS FOUNDATION TRUST   10.447761
# 108      UNIVERSITY HOSPITALS OF DERBY AND BURTON NHS F...    1.685393
# 109            UNIVERSITY HOSPITALS OF LEICESTER NHS TRUST   20.645161
#
# Measure  Missing_Percentage
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ..                      ...
# 105                     NaN
# 106                0.869565
# 107                     NaN
# 108                     NaN
# 109                     NaN
#
# [110 rows x 3 columns]

# %% [markdown]
# We're going to get a few more variables ready to process (Ethnicity, delivery method) and from there we can do a multivariate analysis to find some strong associations.

# %%
final_df_csfpercent = final_df_with_smokers.merge(df_csf_grouped, on='Org_Name', how='left')

final_df_csfpercent.head()
# Out:
#                                             Org_Name Deprivation  \
# 0  ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...    7.218182
# 1  BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...    4.292308
# 2             BARNSLEY HOSPITAL NHS FOUNDATION TRUST    3.723404
# 3                             BARTS HEALTH NHS TRUST     3.22619
# 4        BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST         5.4
#
#    Trauma Percentage Inverted Deprivation  Avg age  Smoker_Percentage  \
# 0          69.565217             0.830999       31           9.433962
# 1          54.838710             3.756873       30           5.384615
# 2          62.962963             4.325776       29          14.893617
# 3          36.434109              4.82299       30           3.930131
# 4          77.586207              2.64918       31           7.368421
#
#    csfpercent  Missing_Percentage
# 0   14.583333                 NaN
# 1   20.370370                 NaN
# 2   11.627907                 NaN
# 3   49.704142            0.393701
# 4   46.969697                 NaN

# %%
df_ethnic_category = dftrusts[dftrusts['Dimension'] == 'EthnicCategoryMotherGroup']

df_ethnic_category = df_ethnic_category[['Dimension', 'Org_Name', 'Measure', 'Final_value']]
for column in df_ethnic_category.columns:
    if df_ethnic_category[column].dtype == 'bool':
        df_ethnic_category[column] = df_ethnic_category[column].astype(int)

df_ethnic_category.head(100)
# Out:
#                        Dimension  \
# 33497  EthnicCategoryMotherGroup
# 33498  EthnicCategoryMotherGroup
# 33499  EthnicCategoryMotherGroup
# 33501  EthnicCategoryMotherGroup
# 33502  EthnicCategoryMotherGroup
# ...                          ...
# 35270  EthnicCategoryMotherGroup
# 35271  EthnicCategoryMotherGroup
# 35272  EthnicCategoryMotherGroup
# 35273  EthnicCategoryMotherGroup
# 35372  EthnicCategoryMotherGroup
#
#                                                 Org_Name  \
# 33497         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33498         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33499         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33501         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# 33502         MANCHESTER UNIVERSITY NHS FOUNDATION TRUST
# ...                                                  ...
# 35270  WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...
# 35271  WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...
# 35272  WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...
# 35273  WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...
# 35372  ST HELENS AND KNOWSLEY TEACHING HOSPITALS NHS ...
#
#                       Measure  Final_value
# 33497  Any other ethnic group           65
# 33498  Asian or Asian British          290
# 33499  Black or Black British          165
# 33501                   Mixed           60
# 33502              Not Stated           45
# ...                       ...          ...
# 35270  Black or Black British            5
# 35271                   Mixed            5
# 35272              Not Stated            5
# 35273                   White          225
# 35372  Any other ethnic group            5
#
# [100 rows x 4 columns]

# %% [markdown]
# Doing one-hot encoding so that we can add these variables to a multivariable analysis as they are non-numeric,  variables, we will do the same for method of birth. Once we've done this we'll chuck all our data into

# %% [markdown]
# The below methods of transformation are very roundabout, this is because I initially was going to turn all the values into boolean, and then decided to opt for the below instead.
#
# Again, as this is a technical project I feel commited to showing technical capability, so doing things in unnecessarily advanced ways in order to achieve simple objectives is, if anything, positive.

# %%
df_encoded = pd.get_dummies(df_ethnic_category, columns=['Measure'])
for column in df_encoded.columns:
    if df_encoded[column].dtype == 'bool':
        df_encoded[column] = df_encoded[column].astype(int)
df_encoded = df_encoded.drop(columns=['Measure_Not known', 'Measure_Not Stated'], errors='ignore')
for index, row in df_encoded.iterrows():
    for col in df_encoded.columns:
        if row[col] == 1:
            df_encoded.at[index, col] = row['Final_value']
df_encoded = df_encoded.groupby('Org_Name').max()
df_encoded.head(50)
# Out:
#                                                                     Dimension  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                       EthnicCategoryMotherGroup
# AIREDALE NHS TRUST                                  EthnicCategoryMotherGroup
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...  EthnicCategoryMotherGroup
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...  EthnicCategoryMotherGroup
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST              EthnicCategoryMotherGroup
# BARTS HEALTH NHS TRUST                              EthnicCategoryMotherGroup
# BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST         EthnicCategoryMotherGroup
# BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATIO...  EthnicCategoryMotherGroup
# BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST   EthnicCategoryMotherGroup
# BOLTON NHS FOUNDATION TRUST                         EthnicCategoryMotherGroup
# BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST    EthnicCategoryMotherGroup
# BUCKINGHAMSHIRE HEALTHCARE NHS TRUST                EthnicCategoryMotherGroup
# CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST    EthnicCategoryMotherGroup
# CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION T...  EthnicCategoryMotherGroup
# CHELSEA AND WESTMINSTER HOSPITAL NHS FOUNDATION...  EthnicCategoryMotherGroup
# CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST    EthnicCategoryMotherGroup
# COUNTESS OF CHESTER HOSPITAL NHS FOUNDATION TRUST   EthnicCategoryMotherGroup
# COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST   EthnicCategoryMotherGroup
# CROYDON HEALTH SERVICES NHS TRUST                   EthnicCategoryMotherGroup
# DARTFORD AND GRAVESHAM NHS TRUST                    EthnicCategoryMotherGroup
# DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS ...  EthnicCategoryMotherGroup
# DORSET COUNTY HOSPITAL NHS FOUNDATION TRUST         EthnicCategoryMotherGroup
# EAST AND NORTH HERTFORDSHIRE NHS TRUST              EthnicCategoryMotherGroup
# EAST CHESHIRE NHS TRUST                             EthnicCategoryMotherGroup
# EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION T...  EthnicCategoryMotherGroup
# EAST LANCASHIRE HOSPITALS NHS TRUST                 EthnicCategoryMotherGroup
# EAST SUFFOLK AND NORTH ESSEX NHS FOUNDATION TRUST   EthnicCategoryMotherGroup
# EAST SUSSEX HEALTHCARE NHS TRUST                    EthnicCategoryMotherGroup
# EPSOM AND ST HELIER UNIVERSITY HOSPITALS NHS TRUST  EthnicCategoryMotherGroup
# FRIMLEY HEALTH NHS FOUNDATION TRUST                 EthnicCategoryMotherGroup
# GATESHEAD HEALTH NHS FOUNDATION TRUST               EthnicCategoryMotherGroup
# GEORGE ELIOT HOSPITAL NHS TRUST                     EthnicCategoryMotherGroup
# GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST      EthnicCategoryMotherGroup
# GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST        EthnicCategoryMotherGroup
# GUY'S AND ST THOMAS' NHS FOUNDATION TRUST           EthnicCategoryMotherGroup
# HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST            EthnicCategoryMotherGroup
# HARROGATE AND DISTRICT NHS FOUNDATION TRUST         EthnicCategoryMotherGroup
# HOMERTON HEALTHCARE NHS FOUNDATION TRUST            EthnicCategoryMotherGroup
# HULL UNIVERSITY TEACHING HOSPITALS NHS TRUST        EthnicCategoryMotherGroup
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST               EthnicCategoryMotherGroup
# ISLE OF WIGHT NHS TRUST                             EthnicCategoryMotherGroup
# JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION...  EthnicCategoryMotherGroup
# KETTERING GENERAL HOSPITAL NHS FOUNDATION TRUST     EthnicCategoryMotherGroup
# KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST        EthnicCategoryMotherGroup
# KINGSTON HOSPITAL NHS FOUNDATION TRUST              EthnicCategoryMotherGroup
# LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION TRUST  EthnicCategoryMotherGroup
# LEEDS TEACHING HOSPITALS NHS TRUST                  EthnicCategoryMotherGroup
# LEWISHAM AND GREENWICH NHS TRUST                    EthnicCategoryMotherGroup
# LIVERPOOL WOMEN'S NHS FOUNDATION TRUST              EthnicCategoryMotherGroup
# LONDON NORTH WEST UNIVERSITY HEALTHCARE NHS TRUST   EthnicCategoryMotherGroup
#
#                                                     Final_value  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                               135
# AIREDALE NHS TRUST                                           95
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...          185
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...          280
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                      210
# BARTS HEALTH NHS TRUST                                      645
# BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST                 275
# BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATIO...          280
# BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST           215
# BOLTON NHS FOUNDATION TRUST                                 205
# BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST            260
# BUCKINGHAMSHIRE HEALTHCARE NHS TRUST                        210
# CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST            260
# CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION T...          380
# CHELSEA AND WESTMINSTER HOSPITAL NHS FOUNDATION...          520
# CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST            250
# COUNTESS OF CHESTER HOSPITAL NHS FOUNDATION TRUST           120
# COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST           410
# CROYDON HEALTH SERVICES NHS TRUST                            90
# DARTFORD AND GRAVESHAM NHS TRUST                            280
# DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS ...          410
# DORSET COUNTY HOSPITAL NHS FOUNDATION TRUST                 125
# EAST AND NORTH HERTFORDSHIRE NHS TRUST                      310
# EAST CHESHIRE NHS TRUST                                      75
# EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION T...          390
# EAST LANCASHIRE HOSPITALS NHS TRUST                         300
# EAST SUFFOLK AND NORTH ESSEX NHS FOUNDATION TRUST           490
# EAST SUSSEX HEALTHCARE NHS TRUST                            235
# EPSOM AND ST HELIER UNIVERSITY HOSPITALS NHS TRUST          225
# FRIMLEY HEALTH NHS FOUNDATION TRUST                         500
# GATESHEAD HEALTH NHS FOUNDATION TRUST                       165
# GEORGE ELIOT HOSPITAL NHS TRUST                             165
# GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST              420
# GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST                255
# GUY'S AND ST THOMAS' NHS FOUNDATION TRUST                   375
# HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST                    375
# HARROGATE AND DISTRICT NHS FOUNDATION TRUST                 125
# HOMERTON HEALTHCARE NHS FOUNDATION TRUST                    260
# HULL UNIVERSITY TEACHING HOSPITALS NHS TRUST                375
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST                       310
# ISLE OF WIGHT NHS TRUST                                      75
# JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION...          135
# KETTERING GENERAL HOSPITAL NHS FOUNDATION TRUST             285
# KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST                420
# KINGSTON HOSPITAL NHS FOUNDATION TRUST                      285
# LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION TRUST          275
# LEEDS TEACHING HOSPITALS NHS TRUST                          595
# LEWISHAM AND GREENWICH NHS TRUST                            335
# LIVERPOOL WOMEN'S NHS FOUNDATION TRUST                      510
# LONDON NORTH WEST UNIVERSITY HEALTHCARE NHS TRUST           220
#
#                                                     Measure_Any other ethnic group  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                    0
# AIREDALE NHS TRUST                                                               0
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                              10
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                              20
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                           5
# BARTS HEALTH NHS TRUST                                                          65
# BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST                                     15
# BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATIO...                              40
# BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST                               10
# BOLTON NHS FOUNDATION TRUST                                                     15
# BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST                                30
# BUCKINGHAMSHIRE HEALTHCARE NHS TRUST                                             5
# CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST                                10
# CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION T...                              25
# CHELSEA AND WESTMINSTER HOSPITAL NHS FOUNDATION...                              80
# CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST                                 5
# COUNTESS OF CHESTER HOSPITAL NHS FOUNDATION TRUST                                5
# COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST                               15
# CROYDON HEALTH SERVICES NHS TRUST                                               20
# DARTFORD AND GRAVESHAM NHS TRUST                                                20
# DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS ...                               5
# DORSET COUNTY HOSPITAL NHS FOUNDATION TRUST                                      5
# EAST AND NORTH HERTFORDSHIRE NHS TRUST                                          15
# EAST CHESHIRE NHS TRUST                                                          0
# EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION T...                              15
# EAST LANCASHIRE HOSPITALS NHS TRUST                                              5
# EAST SUFFOLK AND NORTH ESSEX NHS FOUNDATION TRUST                               20
# EAST SUSSEX HEALTHCARE NHS TRUST                                                 5
# EPSOM AND ST HELIER UNIVERSITY HOSPITALS NHS TRUST                              20
# FRIMLEY HEALTH NHS FOUNDATION TRUST                                             30
# GATESHEAD HEALTH NHS FOUNDATION TRUST                                            5
# GEORGE ELIOT HOSPITAL NHS TRUST                                                  5
# GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST                                  10
# GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST                                    15
# GUY'S AND ST THOMAS' NHS FOUNDATION TRUST                                       60
# HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST                                        10
# HARROGATE AND DISTRICT NHS FOUNDATION TRUST                                      5
# HOMERTON HEALTHCARE NHS FOUNDATION TRUST                                        75
# HULL UNIVERSITY TEACHING HOSPITALS NHS TRUST                                    20
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST                                           90
# ISLE OF WIGHT NHS TRUST                                                          5
# JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION...                               0
# KETTERING GENERAL HOSPITAL NHS FOUNDATION TRUST                                  0
# KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST                                    45
# KINGSTON HOSPITAL NHS FOUNDATION TRUST                                          65
# LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION TRUST                               5
# LEEDS TEACHING HOSPITALS NHS TRUST                                              35
# LEWISHAM AND GREENWICH NHS TRUST                                                40
# LIVERPOOL WOMEN'S NHS FOUNDATION TRUST                                          25
# LONDON NORTH WEST UNIVERSITY HEALTHCARE NHS TRUST                               25
#
#                                                     Measure_Asian or Asian British  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                   45
# AIREDALE NHS TRUST                                                              35
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                              50
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                             235
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                           5
# BARTS HEALTH NHS TRUST                                                         645
# BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST                                    130
# BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATIO...                             255
# BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST                               10
# BOLTON NHS FOUNDATION TRUST                                                     65
# BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST                               260
# BUCKINGHAMSHIRE HEALTHCARE NHS TRUST                                            60
# CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST                                90
# CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION T...                              60
# CHELSEA AND WESTMINSTER HOSPITAL NHS FOUNDATION...                             300
# CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST                                10
# COUNTESS OF CHESTER HOSPITAL NHS FOUNDATION TRUST                                5
# COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST                               10
# CROYDON HEALTH SERVICES NHS TRUST                                               65
# DARTFORD AND GRAVESHAM NHS TRUST                                                50
# DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS ...                              30
# DORSET COUNTY HOSPITAL NHS FOUNDATION TRUST                                      5
# EAST AND NORTH HERTFORDSHIRE NHS TRUST                                          35
# EAST CHESHIRE NHS TRUST                                                          5
# EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION T...                              25
# EAST LANCASHIRE HOSPITALS NHS TRUST                                            155
# EAST SUFFOLK AND NORTH ESSEX NHS FOUNDATION TRUST                               40
# EAST SUSSEX HEALTHCARE NHS TRUST                                                15
# EPSOM AND ST HELIER UNIVERSITY HOSPITALS NHS TRUST                              65
# FRIMLEY HEALTH NHS FOUNDATION TRUST                                            250
# GATESHEAD HEALTH NHS FOUNDATION TRUST                                            5
# GEORGE ELIOT HOSPITAL NHS TRUST                                                 20
# GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST                                  20
# GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST                                    35
# GUY'S AND ST THOMAS' NHS FOUNDATION TRUST                                       80
# HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST                                        40
# HARROGATE AND DISTRICT NHS FOUNDATION TRUST                                      5
# HOMERTON HEALTHCARE NHS FOUNDATION TRUST                                        65
# HULL UNIVERSITY TEACHING HOSPITALS NHS TRUST                                    20
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST                                          180
# ISLE OF WIGHT NHS TRUST                                                          5
# JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION...                              10
# KETTERING GENERAL HOSPITAL NHS FOUNDATION TRUST                                 20
# KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST                                    65
# KINGSTON HOSPITAL NHS FOUNDATION TRUST                                          45
# LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION TRUST                              45
# LEEDS TEACHING HOSPITALS NHS TRUST                                             145
# LEWISHAM AND GREENWICH NHS TRUST                                                90
# LIVERPOOL WOMEN'S NHS FOUNDATION TRUST                                          45
# LONDON NORTH WEST UNIVERSITY HEALTHCARE NHS TRUST                              220
#
#                                                     Measure_Black or Black British  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                    5
# AIREDALE NHS TRUST                                                               5
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                               5
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                              65
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                           5
# BARTS HEALTH NHS TRUST                                                         140
# BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST                                     40
# BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATIO...                              75
# BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST                                5
# BOLTON NHS FOUNDATION TRUST                                                     15
# BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST                                30
# BUCKINGHAMSHIRE HEALTHCARE NHS TRUST                                            10
# CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST                                25
# CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION T...                              15
# CHELSEA AND WESTMINSTER HOSPITAL NHS FOUNDATION...                              70
# CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST                                10
# COUNTESS OF CHESTER HOSPITAL NHS FOUNDATION TRUST                                5
# COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST                                5
# CROYDON HEALTH SERVICES NHS TRUST                                               50
# DARTFORD AND GRAVESHAM NHS TRUST                                                50
# DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS ...                              15
# DORSET COUNTY HOSPITAL NHS FOUNDATION TRUST                                      5
# EAST AND NORTH HERTFORDSHIRE NHS TRUST                                          25
# EAST CHESHIRE NHS TRUST                                                          0
# EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION T...                              10
# EAST LANCASHIRE HOSPITALS NHS TRUST                                              5
# EAST SUFFOLK AND NORTH ESSEX NHS FOUNDATION TRUST                               30
# EAST SUSSEX HEALTHCARE NHS TRUST                                                 5
# EPSOM AND ST HELIER UNIVERSITY HOSPITALS NHS TRUST                              20
# FRIMLEY HEALTH NHS FOUNDATION TRUST                                             50
# GATESHEAD HEALTH NHS FOUNDATION TRUST                                            5
# GEORGE ELIOT HOSPITAL NHS TRUST                                                 10
# GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST                                  15
# GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST                                    20
# GUY'S AND ST THOMAS' NHS FOUNDATION TRUST                                      140
# HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST                                        10
# HARROGATE AND DISTRICT NHS FOUNDATION TRUST                                      5
# HOMERTON HEALTHCARE NHS FOUNDATION TRUST                                        75
# HULL UNIVERSITY TEACHING HOSPITALS NHS TRUST                                    30
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST                                          105
# ISLE OF WIGHT NHS TRUST                                                          0
# JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION...                               5
# KETTERING GENERAL HOSPITAL NHS FOUNDATION TRUST                                 15
# KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST                                   125
# KINGSTON HOSPITAL NHS FOUNDATION TRUST                                           5
# LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION TRUST                              10
# LEEDS TEACHING HOSPITALS NHS TRUST                                              95
# LEWISHAM AND GREENWICH NHS TRUST                                               160
# LIVERPOOL WOMEN'S NHS FOUNDATION TRUST                                          45
# LONDON NORTH WEST UNIVERSITY HEALTHCARE NHS TRUST                               30
#
#                                                     Measure_Mixed  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                   5
# AIREDALE NHS TRUST                                              5
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...              5
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...             25
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                          5
# BARTS HEALTH NHS TRUST                                         25
# BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST                    10
# BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATIO...             30
# BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST               5
# BOLTON NHS FOUNDATION TRUST                                     5
# BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST                5
# BUCKINGHAMSHIRE HEALTHCARE NHS TRUST                           10
# CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST               15
# CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION T...             10
# CHELSEA AND WESTMINSTER HOSPITAL NHS FOUNDATION...             45
# CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST               10
# COUNTESS OF CHESTER HOSPITAL NHS FOUNDATION TRUST               5
# COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST               5
# CROYDON HEALTH SERVICES NHS TRUST                              20
# DARTFORD AND GRAVESHAM NHS TRUST                               10
# DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS ...             10
# DORSET COUNTY HOSPITAL NHS FOUNDATION TRUST                     5
# EAST AND NORTH HERTFORDSHIRE NHS TRUST                         10
# EAST CHESHIRE NHS TRUST                                         5
# EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION T...             15
# EAST LANCASHIRE HOSPITALS NHS TRUST                             5
# EAST SUFFOLK AND NORTH ESSEX NHS FOUNDATION TRUST              10
# EAST SUSSEX HEALTHCARE NHS TRUST                               10
# EPSOM AND ST HELIER UNIVERSITY HOSPITALS NHS TRUST             20
# FRIMLEY HEALTH NHS FOUNDATION TRUST                            30
# GATESHEAD HEALTH NHS FOUNDATION TRUST                           5
# GEORGE ELIOT HOSPITAL NHS TRUST                                 5
# GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST                 15
# GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST                    5
# GUY'S AND ST THOMAS' NHS FOUNDATION TRUST                      40
# HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST                        5
# HARROGATE AND DISTRICT NHS FOUNDATION TRUST                     5
# HOMERTON HEALTHCARE NHS FOUNDATION TRUST                       15
# HULL UNIVERSITY TEACHING HOSPITALS NHS TRUST                   10
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST                          45
# ISLE OF WIGHT NHS TRUST                                         0
# JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION...              5
# KETTERING GENERAL HOSPITAL NHS FOUNDATION TRUST                 5
# KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST                   50
# KINGSTON HOSPITAL NHS FOUNDATION TRUST                          5
# LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION TRUST             10
# LEEDS TEACHING HOSPITALS NHS TRUST                             25
# LEWISHAM AND GREENWICH NHS TRUST                               40
# LIVERPOOL WOMEN'S NHS FOUNDATION TRUST                         15
# LONDON NORTH WEST UNIVERSITY HEALTHCARE NHS TRUST               5
#
#                                                     Measure_White
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                 135
# AIREDALE NHS TRUST                                             95
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...            185
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...            280
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                        210
# BARTS HEALTH NHS TRUST                                        320
# BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST                   275
# BIRMINGHAM WOMEN'S AND CHILDREN'S NHS FOUNDATIO...            280
# BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST             215
# BOLTON NHS FOUNDATION TRUST                                   205
# BRADFORD TEACHING HOSPITALS NHS FOUNDATION TRUST              170
# BUCKINGHAMSHIRE HEALTHCARE NHS TRUST                          210
# CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST              260
# CAMBRIDGE UNIVERSITY HOSPITALS NHS FOUNDATION T...            380
# CHELSEA AND WESTMINSTER HOSPITAL NHS FOUNDATION...            520
# CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST              250
# COUNTESS OF CHESTER HOSPITAL NHS FOUNDATION TRUST             120
# COUNTY DURHAM AND DARLINGTON NHS FOUNDATION TRUST             410
# CROYDON HEALTH SERVICES NHS TRUST                              90
# DARTFORD AND GRAVESHAM NHS TRUST                              280
# DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS ...            410
# DORSET COUNTY HOSPITAL NHS FOUNDATION TRUST                   125
# EAST AND NORTH HERTFORDSHIRE NHS TRUST                        310
# EAST CHESHIRE NHS TRUST                                        75
# EAST KENT HOSPITALS UNIVERSITY NHS FOUNDATION T...            390
# EAST LANCASHIRE HOSPITALS NHS TRUST                           300
# EAST SUFFOLK AND NORTH ESSEX NHS FOUNDATION TRUST             490
# EAST SUSSEX HEALTHCARE NHS TRUST                              235
# EPSOM AND ST HELIER UNIVERSITY HOSPITALS NHS TRUST            225
# FRIMLEY HEALTH NHS FOUNDATION TRUST                           500
# GATESHEAD HEALTH NHS FOUNDATION TRUST                         165
# GEORGE ELIOT HOSPITAL NHS TRUST                               165
# GLOUCESTERSHIRE HOSPITALS NHS FOUNDATION TRUST                420
# GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST                  255
# GUY'S AND ST THOMAS' NHS FOUNDATION TRUST                     375
# HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST                      375
# HARROGATE AND DISTRICT NHS FOUNDATION TRUST                   125
# HOMERTON HEALTHCARE NHS FOUNDATION TRUST                      260
# HULL UNIVERSITY TEACHING HOSPITALS NHS TRUST                  375
# IMPERIAL COLLEGE HEALTHCARE NHS TRUST                         310
# ISLE OF WIGHT NHS TRUST                                        75
# JAMES PAGET UNIVERSITY HOSPITALS NHS FOUNDATION...            135
# KETTERING GENERAL HOSPITAL NHS FOUNDATION TRUST               285
# KING'S COLLEGE HOSPITAL NHS FOUNDATION TRUST                  420
# KINGSTON HOSPITAL NHS FOUNDATION TRUST                        285
# LANCASHIRE TEACHING HOSPITALS NHS FOUNDATION TRUST            275
# LEEDS TEACHING HOSPITALS NHS TRUST                            595
# LEWISHAM AND GREENWICH NHS TRUST                              335
# LIVERPOOL WOMEN'S NHS FOUNDATION TRUST                        510
# LONDON NORTH WEST UNIVERSITY HEALTHCARE NHS TRUST             120

# %%
df_delivery_method = dftrusts[dftrusts['Dimension'] == 'DeliveryMethodBabyGroup']
df_delivery_method = df_delivery_method[['Dimension', 'Org_Name', 'Measure', 'Final_value']]
df_delivery_method_encoded = pd.get_dummies(df_delivery_method, columns=['Measure'])
for column in df_delivery_method_encoded.columns:
    if df_delivery_method_encoded[column].dtype == 'bool':
        df_delivery_method_encoded[column] = df_delivery_method_encoded[column].astype(int)
df_delivery_method_encoded = df_delivery_method_encoded.drop(columns=['Measure_Other'], errors='ignore')
for index, row in df_delivery_method_encoded.iterrows():
    final_value = row['Final_value']  # Capture the final_value for this row
    for col in df_delivery_method_encoded.columns:
        if row[col] == 1:
            df_delivery_method_encoded.at[index, col] = final_value
df_delivery_method_encoded = df_delivery_method_encoded.drop(columns='Final_value')
df_delivery_method_encoded = df_delivery_method_encoded.groupby('Org_Name').max()
df_delivery_method_encoded1 = df_delivery_method_encoded
# Check for duplicate 'Org_Name' in the index before resetting
if 'Org_Name' in df_delivery_method_encoded.index.names:
    duplicate_check = df_delivery_method_encoded.index.get_level_values('Org_Name').duplicated().any()
    print("Duplicates in Org_Name index:", duplicate_check)

df_delivery_method_encoded1
#we will translate these into percentages
# Out:
# Duplicates in Org_Name index: False
#                                                                   Dimension  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                       DeliveryMethodBabyGroup
# AIREDALE NHS TRUST                                  DeliveryMethodBabyGroup
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...  DeliveryMethodBabyGroup
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...  DeliveryMethodBabyGroup
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST              DeliveryMethodBabyGroup
# ...                                                                     ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...  DeliveryMethodBabyGroup
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST            DeliveryMethodBabyGroup
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST  DeliveryMethodBabyGroup
# WYE VALLEY NHS TRUST                                DeliveryMethodBabyGroup
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...  DeliveryMethodBabyGroup
#
#                                                     Measure_Elective caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                       30
# AIREDALE NHS TRUST                                                                  30
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                                  65
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                                  85
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                               5
# ...                                                                                ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                                  45
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                            65
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                                  35
# WYE VALLEY NHS TRUST                                                                25
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                                  45
#
#                                                     Measure_Emergency caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                        25
# AIREDALE NHS TRUST                                                                   25
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                                   65
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                                  140
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                               35
# ...                                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                                   50
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                             60
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                                   35
# WYE VALLEY NHS TRUST                                                                 30
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                                   55
#
#                                                     Measure_Instrumental  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                         15
# AIREDALE NHS TRUST                                                    15
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                    20
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                    40
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                10
# ...                                                                  ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                    25
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                              35
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                     5
# WYE VALLEY NHS TRUST                                                  10
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                    25
#
#                                                     Measure_Spontaneous
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                        80
# AIREDALE NHS TRUST                                                   75
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                   90
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                  280
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                              130
# ...                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                  110
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                            190
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                   80
# WYE VALLEY NHS TRUST                                                 45
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                  160
#
# [123 rows x 5 columns]

# %%
if 'Org_Name' in df_delivery_method_encoded.index.names:
    df_delivery_method_encoded.fillna(value=0, inplace=True)
df_delivery_method_encoded[2:5] = df_delivery_method_encoded[2:5].apply(pd.to_numeric, errors='coerce')
numeric_cols = df_delivery_method_encoded.select_dtypes(include=[np.number]).columns.tolist()
df_delivery_method_encoded['Row_Sum'] = df_delivery_method_encoded[numeric_cols].sum(axis=1)

for col in numeric_cols:
    df_delivery_method_encoded[col] = df_delivery_method_encoded[col] / df_delivery_method_encoded['Row_Sum'] * 100

df_delivery_method_encoded.drop('Row_Sum', axis=1, inplace=True)
df_delivery_method_encoded
# Out:
#                                                                   Dimension  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                       DeliveryMethodBabyGroup
# AIREDALE NHS TRUST                                  DeliveryMethodBabyGroup
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                      NaN
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                      NaN
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                  NaN
# ...                                                                     ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...  DeliveryMethodBabyGroup
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST            DeliveryMethodBabyGroup
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST  DeliveryMethodBabyGroup
# WYE VALLEY NHS TRUST                                DeliveryMethodBabyGroup
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...  DeliveryMethodBabyGroup
#
#                                                     Measure_Elective caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                20.000000
# AIREDALE NHS TRUST                                                           20.689655
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                           27.083333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                           15.596330
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                        2.777778
# ...                                                                                ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                           19.565217
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                     18.571429
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                           22.580645
# WYE VALLEY NHS TRUST                                                         22.727273
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                           15.789474
#
#                                                     Measure_Emergency caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                 16.666667
# AIREDALE NHS TRUST                                                            17.241379
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                            27.083333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                            25.688073
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                        19.444444
# ...                                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                            21.739130
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                      17.142857
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                            22.580645
# WYE VALLEY NHS TRUST                                                          27.272727
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                            19.298246
#
#                                                     Measure_Instrumental  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                  10.000000
# AIREDALE NHS TRUST                                             10.344828
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...              8.333333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...              7.339450
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                          5.555556
# ...                                                                  ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...             10.869565
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                       10.000000
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST              3.225806
# WYE VALLEY NHS TRUST                                            9.090909
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...              8.771930
#
#                                                     Measure_Spontaneous
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                 53.333333
# AIREDALE NHS TRUST                                            51.724138
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...            37.500000
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...            51.376147
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                        72.222222
# ...                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...            47.826087
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                      54.285714
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST            51.612903
# WYE VALLEY NHS TRUST                                          40.909091
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...            56.140351
#
# [123 rows x 5 columns]

# %%
if 'Org_Name' in df_delivery_method_encoded.index.names:
    df_delivery_method_encoded.fillna(value=0, inplace=True)

if 'Org_Name' in df_delivery_method_encoded1.index.names:
    df_delivery_method_encoded.fillna(value=0, inplace=True)

print("Columns in df_delivery_method_encoded:", df_delivery_method_encoded.columns)
print("Columns in df_delivery_method_encoded1:", df_delivery_method_encoded1.columns)

org_names_in_encoded = set(df_delivery_method_encoded['Org_Name'])
org_names_in_encoded1 = set(df_delivery_method_encoded1['Org_Name'])

missing_org_names = org_names_in_encoded1.difference(org_names_in_encoded)

print("Org_Names missing from df_delivery_method_encoded:")
print(missing_org_names)
# Out:
# Columns in df_delivery_method_encoded: Index(['Dimension', 'Measure_Elective caesarean section',
#        'Measure_Emergency caesarean section', 'Measure_Instrumental',
#        'Measure_Spontaneous'],
#       dtype='object')
# Columns in df_delivery_method_encoded1: Index(['Dimension', 'Measure_Elective caesarean section',
#        'Measure_Emergency caesarean section', 'Measure_Instrumental',
#        'Measure_Spontaneous'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Org_Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 11
#       8 print("Columns in df_delivery_method_encoded:", df_delivery_method_encoded.columns)
#       9 print("Columns in df_delivery_method_encoded1:", df_delivery_method_encoded1.columns)
# ---> 11 org_names_in_encoded = set(df_delivery_method_encoded['Org_Name'])
#      12 org_names_in_encoded1 = set(df_delivery_method_encoded1['Org_Name'])
#      14 # Find Org_Names that are in df_delivery_method_encoded1 but not in df_delivery_method_encoded
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Org_Name'

# %%
df_delivery_method_encoded
# Out:
#                                                                   Dimension  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                       DeliveryMethodBabyGroup
# AIREDALE NHS TRUST                                  DeliveryMethodBabyGroup
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                        0
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                        0
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                    0
# ...                                                                     ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...  DeliveryMethodBabyGroup
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST            DeliveryMethodBabyGroup
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST  DeliveryMethodBabyGroup
# WYE VALLEY NHS TRUST                                DeliveryMethodBabyGroup
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...  DeliveryMethodBabyGroup
#
#                                                     Measure_Elective caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                20.000000
# AIREDALE NHS TRUST                                                           20.689655
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                           27.083333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                           15.596330
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                        2.777778
# ...                                                                                ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                           19.565217
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                     18.571429
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                           22.580645
# WYE VALLEY NHS TRUST                                                         22.727273
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                           15.789474
#
#                                                     Measure_Emergency caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                 16.666667
# AIREDALE NHS TRUST                                                            17.241379
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                            27.083333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                            25.688073
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                        19.444444
# ...                                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                            21.739130
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                      17.142857
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                            22.580645
# WYE VALLEY NHS TRUST                                                          27.272727
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                            19.298246
#
#                                                     Measure_Instrumental  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                  10.000000
# AIREDALE NHS TRUST                                             10.344828
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...              8.333333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...              7.339450
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                          5.555556
# ...                                                                  ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...             10.869565
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                       10.000000
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST              3.225806
# WYE VALLEY NHS TRUST                                            9.090909
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...              8.771930
#
#                                                     Measure_Spontaneous
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                 53.333333
# AIREDALE NHS TRUST                                            51.724138
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...            37.500000
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...            51.376147
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                        72.222222
# ...                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...            47.826087
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                      54.285714
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST            51.612903
# WYE VALLEY NHS TRUST                                          40.909091
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...            56.140351
#
# [123 rows x 5 columns]

# %%
df_delivery_method_encoded1
# Out:
#                                                                   Dimension  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                       DeliveryMethodBabyGroup
# AIREDALE NHS TRUST                                  DeliveryMethodBabyGroup
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                        0
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                        0
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                    0
# ...                                                                     ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...  DeliveryMethodBabyGroup
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST            DeliveryMethodBabyGroup
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST  DeliveryMethodBabyGroup
# WYE VALLEY NHS TRUST                                DeliveryMethodBabyGroup
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...  DeliveryMethodBabyGroup
#
#                                                     Measure_Elective caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                20.000000
# AIREDALE NHS TRUST                                                           20.689655
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                           27.083333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                           15.596330
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                        2.777778
# ...                                                                                ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                           19.565217
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                     18.571429
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                           22.580645
# WYE VALLEY NHS TRUST                                                         22.727273
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                           15.789474
#
#                                                     Measure_Emergency caesarean section  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                                 16.666667
# AIREDALE NHS TRUST                                                            17.241379
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...                            27.083333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...                            25.688073
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                                        19.444444
# ...                                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...                            21.739130
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                                      17.142857
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST                            22.580645
# WYE VALLEY NHS TRUST                                                          27.272727
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...                            19.298246
#
#                                                     Measure_Instrumental  \
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                  10.000000
# AIREDALE NHS TRUST                                             10.344828
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...              8.333333
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...              7.339450
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                          5.555556
# ...                                                                  ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...             10.869565
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                       10.000000
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST              3.225806
# WYE VALLEY NHS TRUST                                            9.090909
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...              8.771930
#
#                                                     Measure_Spontaneous
# Org_Name
# AIREDALE NHS FOUNDATION TRUST                                 53.333333
# AIREDALE NHS TRUST                                            51.724138
# ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATION...            37.500000
# BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOSP...            51.376147
# BARNSLEY HOSPITAL NHS FOUNDATION TRUST                        72.222222
# ...                                                                 ...
# WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDAT...            47.826087
# WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST                      54.285714
# WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION TRUST            51.612903
# WYE VALLEY NHS TRUST                                          40.909091
# YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FOU...            56.140351
#
# [123 rows x 5 columns]

# %%
for column in df_encoded.columns:
    if df_encoded[column].dtype == 'bool':
        df_encoded[column] = df_encoded[column].astype(int)
numeric_cols = df_encoded.select_dtypes(include=[np.number]).columns.tolist()
df_encoded['Row_Sum'] = df_encoded[numeric_cols].sum(axis=1)
for col in numeric_cols:
    df_encoded[col] = df_encoded[col] / df_encoded['Row_Sum'] * 100
df_encoded.drop('Row_Sum', axis=1, inplace=True)
df_encoded = df_encoded.groupby('Org_Name').max()
if 'Org_Name' in df_encoded.index.names:
    df_encoded.reset_index(inplace=True)
if 'Final_value' in df_encoded.columns:
    df_encoded = df_encoded.drop(columns='Final_value')
df_encoded.head(100)
# Out:
#                                              Org_Name  \
# 0                       AIREDALE NHS FOUNDATION TRUST
# 1                                  AIREDALE NHS TRUST
# 2   ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...
# 3   BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...
# 4              BARNSLEY HOSPITAL NHS FOUNDATION TRUST
# ..                                                ...
# 95          THE PRINCESS ALEXANDRA HOSPITAL NHS TRUST
# 96  THE QUEEN ELIZABETH HOSPITAL, KING'S LYNN, NHS...
# 97                 THE ROTHERHAM NHS FOUNDATION TRUST
# 98                  THE ROYAL WOLVERHAMPTON NHS TRUST
# 99      THE SHREWSBURY AND TELFORD HOSPITAL NHS TRUST
#
#                     Dimension  Measure_Any other ethnic group  \
# 0   EthnicCategoryMotherGroup                        0.000000
# 1   EthnicCategoryMotherGroup                        0.000000
# 2   EthnicCategoryMotherGroup                        2.272727
# 3   EthnicCategoryMotherGroup                        2.209945
# 4   EthnicCategoryMotherGroup                        1.136364
# ..                        ...                             ...
# 95  EthnicCategoryMotherGroup                        0.826446
# 96  EthnicCategoryMotherGroup                        1.724138
# 97  EthnicCategoryMotherGroup                        3.225806
# 98  EthnicCategoryMotherGroup                        2.453988
# 99  EthnicCategoryMotherGroup                        0.609756
#
#     Measure_Asian or Asian British  Measure_Black or Black British  \
# 0                        13.846154                        1.538462
# 1                        14.893617                        2.127660
# 2                        11.363636                        1.136364
# 3                        25.966851                        7.182320
# 4                         1.136364                        1.136364
# ..                             ...                             ...
# 95                        2.479339                        3.305785
# 96                        1.724138                        1.724138
# 97                        6.451613                        1.612903
# 98                       11.656442                        7.361963
# 99                        3.658537                        1.829268
#
#     Measure_Mixed  Measure_White
# 0        1.538462      41.538462
# 1        2.127660      40.425532
# 2        1.136364      42.045455
# 3        2.762431      30.939227
# 4        1.136364      47.727273
# ..            ...            ...
# 95       0.826446      46.280992
# 96       1.724138      46.551724
# 97       1.612903      43.548387
# 98       2.453988      38.036810
# 99       1.219512      46.341463
#
# [100 rows x 7 columns]

# %%
df_delivery_method_encoded = df_delivery_method_encoded.drop(columns=['Dimension'], errors='ignore')
df_encoded = df_encoded.drop(columns=['Dimension'], errors='ignore')

# %%
merged_df = pd.merge(df_encoded, df_delivery_method_encoded, on='Org_Name', how='outer')
centraldf = pd.merge(merged_df, final_df_csfpercent, on='Org_Name', how='outer')
#I'm going to drop Airedale as they have so many nan values
centraldf = centraldf[~centraldf['Org_Name'].str.startswith('AIREDALE')]
#Fixed
centraldf = centraldf.drop(columns=['Missing_Percentage'], errors='ignore')
centraldf = centraldf.drop(columns=['Final_value'], errors='ignore')
centraldf
# Out:
#                                               Org_Name  \
# 2    ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...
# 3    BARKING, HAVERING AND REDBRIDGE UNIVERSITY HOS...
# 4               BARNSLEY HOSPITAL NHS FOUNDATION TRUST
# 5                               BARTS HEALTH NHS TRUST
# 6          BEDFORDSHIRE HOSPITALS NHS FOUNDATION TRUST
# ..                                                 ...
# 120  WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...
# 121           WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST
# 122  WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION T...
# 123                               WYE VALLEY NHS TRUST
# 124  YORK AND SCARBOROUGH TEACHING HOSPITALS NHS FO...
#
#      Measure_Any other ethnic group  Measure_Asian or Asian British  \
# 2                          2.272727                       11.363636
# 3                          2.209945                       25.966851
# 4                          1.136364                        1.136364
# 5                          3.532609                       35.054348
# 6                          2.013423                       17.449664
# ..                              ...                             ...
# 120                        1.063830                        1.063830
# 121                        0.645161                        3.870968
# 122                        1.492537                        1.492537
# 123                        0.000000                        1.886792
# 124                        0.000000                        0.000000
#
#      Measure_Black or Black British  Measure_Mixed  Measure_White  \
# 2                          1.136364       1.136364      42.045455
# 3                          7.182320       2.762431      30.939227
# 4                          1.136364       1.136364      47.727273
# 5                          7.608696       1.358696      17.391304
# 6                          5.369128       1.342282      36.912752
# ..                              ...            ...            ...
# 120                        1.063830       1.063830      47.872340
# 121                        0.645161       0.645161      47.096774
# 122                        2.985075       1.492537      46.268657
# 123                        1.886792       1.886792      47.169811
# 124                        0.000000       0.000000      50.000000
#
#      Measure_Elective caesarean section  Measure_Emergency caesarean section  \
# 2                             27.083333                            27.083333
# 3                             15.596330                            25.688073
# 4                              2.777778                            19.444444
# 5                             11.734694                            21.938776
# 6                             18.181818                            22.222222
# ..                                  ...                                  ...
# 120                           19.565217                            21.739130
# 121                           18.571429                            17.142857
# 122                           22.580645                            22.580645
# 123                           22.727273                            27.272727
# 124                           15.789474                            19.298246
#
#      Measure_Instrumental  Measure_Spontaneous Deprivation  Trauma Percentage  \
# 2                8.333333            37.500000    7.218182          69.565217
# 3                7.339450            51.376147    4.292308          54.838710
# 4                5.555556            72.222222    3.723404          62.962963
# 5               11.224490            55.102041     3.22619          36.434109
# 6                8.080808            51.515152         5.4          77.586207
# ..                    ...                  ...         ...                ...
# 120             10.869565            47.826087    4.166667          55.555556
# 121             10.000000            54.285714    5.744444          68.888889
# 122              3.225806            51.612903    4.514286          54.545455
# 123              9.090909            40.909091    5.354839          75.000000
# 124              8.771930            56.140351         NaN                NaN
#
#     Inverted Deprivation  Avg age  Smoker_Percentage  csfpercent
# 2               0.830999     31.0           9.433962   14.583333
# 3               3.756873     30.0           5.384615   20.370370
# 4               4.325776     29.0          14.893617   11.627907
# 5                4.82299     30.0           3.930131   49.704142
# 6                2.64918     31.0           7.368421   46.969697
# ..                   ...      ...                ...         ...
# 120             3.882514     29.0          10.000000    6.382979
# 121             2.304736     30.0          13.483146    9.876543
# 122             3.534895     29.0           8.571429   12.903226
# 123             2.694342     30.0          10.344828   11.538462
# 124                  NaN      NaN                NaN         NaN
#
# [123 rows x 16 columns]

# %%
print(model.summary())

output_notebook()

source = ColumnDataSource(data={
    'x': centraldf['Smoker_Percentage'],
    'y': centraldf['csfpercent'],
    'Org_Name': centraldf['Org_Name']
})

p = figure(title="Smoker Percentage vs. CSF Percentage",
           x_axis_label='Smoker Percentage',
           y_axis_label='CSF Percentage',
           tools="pan,wheel_zoom,box_zoom,reset")

p.circle('x', 'y', size=10, source=source, color="navy", alpha=0.5)

hover = HoverTool()
hover.tooltips = [("Org_Name", "@Org_Name"),
                  ("Smoker_Percentage", "@x"),
                  ("CSF_Percentage", "@y")]

p.add_tools(hover)

show(p)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Trauma Percentage   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     2.330
# Date:                Thu, 29 Aug 2024   Prob (F-statistic):             0.0368
# Time:                        16:32:02   Log-Likelihood:                -460.21
# No. Observations:                 123   AIC:                             934.4
# Df Residuals:                     116   BIC:                             954.1
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  98.4966     34.967      2.817      0.006      29.241     167.753
# Smoker_Percentage                       0.2937      0.121      2.420      0.017       0.053       0.534
# csfpercent                              0.0249      0.100      0.250      0.803      -0.173       0.223
# Measure_Elective caesarean section      0.3673      0.180      2.036      0.044       0.010       0.725
# Measure_Emergency caesarean section     0.0635      0.180      0.352      0.725      -0.294       0.420
# Inverted Deprivation                   -2.1206      0.989     -2.143      0.034      -4.080      -0.161
# Avg age                                -1.2828      1.104     -1.162      0.248      -3.469       0.903
# ==============================================================================
# Omnibus:                        6.099   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.649
# Skew:                          -0.506   Prob(JB):                       0.0593
# Kurtosis:                       3.278   Cond. No.                     1.66e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e80c571a-526f-435c-b66f-3f180826b090">Loading BokehJS ...</span>
#     </div>
#   <div id="f49f33ca-8076-4b36-8f3e-4c05817ff15e" data-root-id="p1764" style="display: contents;"></div>

# %% [markdown]
# We will now find correlations between all of our data

# %%
correlation = centraldf.copy()
correlation = correlation.drop(columns=['Org_Name'])

columns_of_interest = [
    'Measure_Elective caesarean section',
    'Measure_Emergency caesarean section',
    'Inverted Deprivation',
    'Trauma Percentage',
    'Smoker_Percentage',
    'csfpercent'
]

results = []

for col1 in columns_of_interest:
    for col2 in correlation.columns:
        if col1 != col2 and col2 not in columns_of_interest:
            x = correlation[col1].dropna()
            y = correlation[col2].dropna()
            
            common_index = x.index.intersection(y.index)
            x = x.loc[common_index]
            y = y.loc[common_index]
            
            if len(x) > 0 and len(y) > 0 and len(x) == len(y):
                r, p_value = pearson_correlation_with_pvalue_debug(x, y)
                results.append({
                    'Measure': col1,
                    'ComparedMeasure': col2,
                    'Pearson Correlation': r,
                    'P-value': p_value
                })

correlationfin = pd.DataFrame(results)
pd.options.display.float_format = '{:.2f}'.format

correlationfin
# Out:
# Pearson correlation coefficient is exactly 1 or -1.
#                                 Measure                 ComparedMeasure  \
# 0    Measure_Elective caesarean section  Measure_Any other ethnic group
# 1    Measure_Elective caesarean section  Measure_Asian or Asian British
# 2    Measure_Elective caesarean section  Measure_Black or Black British
# 3    Measure_Elective caesarean section                   Measure_Mixed
# 4    Measure_Elective caesarean section                   Measure_White
# 5    Measure_Elective caesarean section            Measure_Instrumental
# 6    Measure_Elective caesarean section             Measure_Spontaneous
# 7    Measure_Elective caesarean section                     Deprivation
# 8    Measure_Elective caesarean section                         Avg age
# 9   Measure_Emergency caesarean section  Measure_Any other ethnic group
# 10  Measure_Emergency caesarean section  Measure_Asian or Asian British
# 11  Measure_Emergency caesarean section  Measure_Black or Black British
# 12  Measure_Emergency caesarean section                   Measure_Mixed
# 13  Measure_Emergency caesarean section                   Measure_White
# 14  Measure_Emergency caesarean section            Measure_Instrumental
# 15  Measure_Emergency caesarean section             Measure_Spontaneous
# 16  Measure_Emergency caesarean section                     Deprivation
# 17  Measure_Emergency caesarean section                         Avg age
# 18                 Inverted Deprivation  Measure_Any other ethnic group
# 19                 Inverted Deprivation  Measure_Asian or Asian British
# 20                 Inverted Deprivation  Measure_Black or Black British
# 21                 Inverted Deprivation                   Measure_Mixed
# 22                 Inverted Deprivation                   Measure_White
# 23                 Inverted Deprivation            Measure_Instrumental
# 24                 Inverted Deprivation             Measure_Spontaneous
# 25                 Inverted Deprivation                     Deprivation
# 26                 Inverted Deprivation                         Avg age
# 27                    Trauma Percentage  Measure_Any other ethnic group
# 28                    Trauma Percentage  Measure_Asian or Asian British
# 29                    Trauma Percentage  Measure_Black or Black British
# 30                    Trauma Percentage                   Measure_Mixed
# 31                    Trauma Percentage                   Measure_White
# 32                    Trauma Percentage            Measure_Instrumental
# 33                    Trauma Percentage             Measure_Spontaneous
# 34                    Trauma Percentage                     Deprivation
# 35                    Trauma Percentage                         Avg age
# 36                    Smoker_Percentage  Measure_Any other ethnic group
# 37                    Smoker_Percentage  Measure_Asian or Asian British
# 38                    Smoker_Percentage  Measure_Black or Black British
# 39                    Smoker_Percentage                   Measure_Mixed
# 40                    Smoker_Percentage                   Measure_White
# 41                    Smoker_Percentage            Measure_Instrumental
# 42                    Smoker_Percentage             Measure_Spontaneous
# 43                    Smoker_Percentage                     Deprivation
# 44                    Smoker_Percentage                         Avg age
# 45                           csfpercent  Measure_Any other ethnic group
# 46                           csfpercent  Measure_Asian or Asian British
# 47                           csfpercent  Measure_Black or Black British
# 48                           csfpercent                   Measure_Mixed
# 49                           csfpercent                   Measure_White
# 50                           csfpercent            Measure_Instrumental
# 51                           csfpercent             Measure_Spontaneous
# 52                           csfpercent                     Deprivation
# 53                           csfpercent                         Avg age
#
#     Pearson Correlation  P-value
# 0                  0.11     0.23
# 1                 -0.01     0.94
# 2                  0.06     0.51
# 3                 -0.03     0.71
# 4                 -0.01     0.92
# 5                  0.03     0.74
# 6                 -0.59  < 1e-10
# 7                  0.05     0.57
# 8                  0.11     0.22
# 9                  0.14     0.12
# 10                 0.23     0.01
# 11                 0.25     0.01
# 12                 0.18     0.04
# 13                -0.26     0.00
# 14                 0.08     0.39
# 15                -0.63  < 1e-10
# 16                -0.10     0.30
# 17                -0.00     0.98
# 18                 0.16     0.09
# 19                 0.25     0.01
# 20                 0.32     0.00
# 21                 0.14     0.12
# 22                -0.31     0.00
# 23                 0.02     0.86
# 24                -0.04     0.67
# 25                -1.00     0.00
# 26                -0.56  < 1e-10
# 27                -0.07     0.47
# 28                -0.11     0.25
# 29                -0.20     0.03
# 30                -0.11     0.26
# 31                 0.16     0.09
# 32                 0.04     0.67
# 33                -0.14     0.15
# 34                 0.14     0.14
# 35                -0.02     0.86
# 36                -0.04     0.64
# 37                -0.01     0.88
# 38                -0.17     0.07
# 39                -0.04     0.70
# 40                 0.08     0.41
# 41                -0.13     0.18
# 42                 0.03     0.78
# 43                -0.14     0.14
# 44                -0.20     0.03
# 45                 0.17     0.08
# 46                 0.47     0.00
# 47                 0.43     0.00
# 48                 0.18     0.05
# 49                -0.52     0.00
# 50                -0.03     0.71
# 51                -0.11     0.26
# 52                -0.34     0.00
# 53                -0.11     0.24

# %%
import statsmodels.api as sm
centraldf_filled = centraldf
centraldf_filled = centraldf_filled.drop(columns=['Org_Name'], errors='ignore')

centraldf_filled = centraldf_filled.fillna(centraldf_filled.mean())

Y = centraldf_filled['Trauma Percentage']

X = centraldf_filled[['Smoker_Percentage', 'csfpercent', 'Measure_Elective caesarean section', 
                      'Measure_Emergency caesarean section', 'Inverted Deprivation', 'Avg age']]

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      Trauma Percentage   R-squared:                       0.108
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     2.330
# Date:                Thu, 29 Aug 2024   Prob (F-statistic):             0.0368
# Time:                        15:01:15   Log-Likelihood:                -460.21
# No. Observations:                 123   AIC:                             934.4
# Df Residuals:                     116   BIC:                             954.1
# Df Model:                           6
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  98.4966     34.967      2.817      0.006      29.241     167.753
# Smoker_Percentage                       0.2937      0.121      2.420      0.017       0.053       0.534
# csfpercent                              0.0249      0.100      0.250      0.803      -0.173       0.223
# Measure_Elective caesarean section      0.3673      0.180      2.036      0.044       0.010       0.725
# Measure_Emergency caesarean section     0.0635      0.180      0.352      0.725      -0.294       0.420
# Inverted Deprivation                   -2.1206      0.989     -2.143      0.034      -4.080      -0.161
# Avg age                                -1.2828      1.104     -1.162      0.248      -3.469       0.903
# ==============================================================================
# Omnibus:                        6.099   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                5.649
# Skew:                          -0.506   Prob(JB):                       0.0593
# Kurtosis:                       3.278   Cond. No.                     1.66e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Moving on to visualisation here, I could spend forever refitting these calculations to optimise and realistically they could still result in nothing due to contaminated date (poor reporting sources, again not all trusts are poor at reporting but enough to make these not interpretable in a valuable way.

# %%
output_notebook()

hist, edges = np.histogram(centraldf['Smoker_Percentage'].dropna(), bins=20)

source = ColumnDataSource(data={
    'top': hist,
    'left': edges[:-1],
    'right': edges[1:]
})

p = figure(title="Histogram of Smoker Percentage",
           x_axis_label='Smoker Percentage',
           y_axis_label='Frequency',
           tools="pan,wheel_zoom,box_zoom,reset")

p.quad(top='top', bottom=0, left='left', right='right', source=source, 
       fill_color="navy", line_color="white", alpha=0.7)

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ad07f7ca-bbc1-4242-ad8b-b78bd92219b9">Loading BokehJS ...</span>
#     </div>
#   <div id="da84ca1b-d6a3-4f78-84dd-36ef9fe0784b" data-root-id="p1050" style="display: contents;"></div>

# %%
centraldf_no_outliers = remove_outliers(centraldf)
centraldf_no_outliers
# Out:
#                                               Org_Name  \
# 8    BLACKPOOL TEACHING HOSPITALS NHS FOUNDATION TRUST
# 9                          BOLTON NHS FOUNDATION TRUST
# 11                BUCKINGHAMSHIRE HEALTHCARE NHS TRUST
# 12    CALDERDALE AND HUDDERSFIELD NHS FOUNDATION TRUST
# 15    CHESTERFIELD ROYAL HOSPITAL NHS FOUNDATION TRUST
# ..                                                 ...
# 118                  WEST SUFFOLK NHS FOUNDATION TRUST
# 120  WIRRAL UNIVERSITY TEACHING HOSPITAL NHS FOUNDA...
# 121           WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST
# 122  WRIGHTINGTON, WIGAN AND LEIGH NHS FOUNDATION T...
# 123                               WYE VALLEY NHS TRUST
#
#      Measure_Any other ethnic group  Measure_Asian or Asian British  \
# 8                              2.17                            2.17
# 9                              2.94                           12.75
# 11                             0.99                           11.88
# 12                             1.52                           13.64
# 15                             0.93                            1.87
# ..                              ...                             ...
# 118                            1.25                            2.50
# 120                            1.06                            1.06
# 121                            0.65                            3.87
# 122                            1.49                            1.49
# 123                            0.00                            1.89
#
#      Measure_Black or Black British  Measure_Mixed  Measure_White  \
# 8                              1.09           1.09          46.74
# 9                              2.94           0.98          40.20
# 11                             1.98           1.98          41.58
# 12                             3.79           2.27          39.39
# 15                             1.87           1.87          46.73
# ..                              ...            ...            ...
# 118                            1.25           2.50          46.25
# 120                            1.06           1.06          47.87
# 121                            0.65           0.65          47.10
# 122                            2.99           1.49          46.27
# 123                            1.89           1.89          47.17
#
#      Measure_Elective caesarean section  Measure_Emergency caesarean section  \
# 8                                 17.02                                25.53
# 9                                 13.16                                21.05
# 11                                14.00                                20.00
# 12                                14.29                                23.21
# 15                                13.95                                25.58
# ..                                  ...                                  ...
# 118                               15.15                                15.15
# 120                               19.57                                21.74
# 121                               18.57                                17.14
# 122                               22.58                                22.58
# 123                               22.73                                27.27
#
#      Measure_Instrumental  Measure_Spontaneous Deprivation  Trauma Percentage  \
# 8                   10.64                46.81        3.72              73.91
# 9                   11.84                53.95        3.92              43.75
# 11                   6.00                60.00        7.58              71.88
# 12                   8.93                53.57        4.23              60.61
# 15                  13.95                46.51        4.90              72.00
# ..                    ...                  ...         ...                ...
# 118                  9.09                60.61        5.93              60.87
# 120                 10.87                47.83        4.17              55.56
# 121                 10.00                54.29        5.74              68.89
# 122                  3.23                51.61        4.51              54.55
# 123                  9.09                40.91        5.35              75.00
#
#     Inverted Deprivation  Avg age  Smoker_Percentage  csfpercent
# 8                   4.33    29.00              19.05       16.28
# 9                   4.13    30.00              10.00       13.64
# 11                  0.46    32.00               5.06        9.86
# 12                  3.81    30.00              11.39       23.81
# 15                  3.15    30.00               9.26       16.33
# ..                   ...      ...                ...         ...
# 118                 2.12    30.00               9.09       13.16
# 120                 3.88    29.00              10.00        6.38
# 121                 2.30    30.00              13.48        9.88
# 122                 3.53    29.00               8.57       12.90
# 123                 2.69    30.00              10.34       11.54
#
# [79 rows x 16 columns]

# %%
output_notebook()

source = ColumnDataSource(data={
    'x': centraldf_no_outliers['Smoker_Percentage'],
    'y': centraldf_no_outliers['Inverted Deprivation'],
    'Org_Name': centraldf_no_outliers['Org_Name']
})

p = figure(title="Smoker Percentage vs. Deprivation",
           x_axis_label='Smoker Percentage',
           y_axis_label='Deprivation',
           tools="pan,wheel_zoom,box_zoom,reset")

p.circle('x', 'y', size=10, source=source, color="navy", alpha=0.5)

hover = HoverTool()
hover.tooltips = [("Org_Name", "@Org_Name"),
                  ("Smoker_Percentage", "@x"),
                  ("Deprivation", "@y")]

p.add_tools(hover)

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="baf4a90e-e87c-4407-b907-d32084d435c3">Loading BokehJS ...</span>
#     </div>
#   <div id="ec504b0d-4ad2-491d-8d19-5be22489ab6d" data-root-id="p1321" style="display: contents;"></div>

# %%
# Out:
# The average ratio of Deprivation to Smoker Percentage is: 0.29

# %%
output_notebook()

centraldf_no_outliers['Smoker_Percentage'] = pd.to_numeric(centraldf_no_outliers['Smoker_Percentage'], errors='coerce')
centraldf_no_outliers['Inverted Deprivation'] = pd.to_numeric(centraldf_no_outliers['Inverted Deprivation'], errors='coerce')

centraldf_no_outliers = centraldf_no_outliers.dropna(subset=['Smoker_Percentage', 'Inverted Deprivation'])

source = ColumnDataSource(data={
    'x': centraldf_no_outliers['Smoker_Percentage'],
    'y': centraldf_no_outliers['Inverted Deprivation'],
    'Org_Name': centraldf_no_outliers['Org_Name']
})

p = figure(title="Smoker Percentage vs. Deprivation with Trend Line",
           x_axis_label='Smoker Percentage',
           y_axis_label='Deprivation',
           tools="pan,wheel_zoom,box_zoom,reset")

p.circle('x', 'y', size=10, source=source, color="navy", alpha=0.5)

hover = HoverTool()
hover.tooltips = [("Org_Name", "@Org_Name"),
                  ("Smoker_Percentage", "@x"),
                  ("Deprivation (Higher = more deprived)", "@y")]

p.add_tools(hover)

#(linear regression)
x = centraldf_no_outliers['Smoker_Percentage']
y = centraldf_no_outliers['Inverted Deprivation']

#(y = mx + c)
p_coeff = np.polyfit(x, y, 1)
y_fit = np.polyval(p_coeff, x)

p.line(x, y_fit, color="red", line_width=2, legend_label="Average smoker to deprivation ratio")

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="da548105-c8f7-4a92-aea7-6e340fad9c46">Loading BokehJS ...</span>
#     </div>
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b9354845-e176-4678-a23f-26bd367fb2dc">Loading BokehJS ...</span>
#     </div>
#   <div id="ae3217f5-a67e-4fa9-92d0-5185701870d7" data-root-id="p1587" style="display: contents;"></div>

# %%
output_notebook()

centraldf_no_outliers['Measure_Black or Black British'] = pd.to_numeric(centraldf_no_outliers['Measure_Black or Black British'], errors='coerce')
centraldf_no_outliers['Measure_Emergency caesarean section'] = pd.to_numeric(centraldf_no_outliers['Measure_Emergency caesarean section'], errors='coerce')

centraldf_no_outliers = centraldf_no_outliers.dropna(subset=['Measure_Black or Black British', 'Measure_Emergency caesarean section'])

source = ColumnDataSource(data={
    'x': centraldf_no_outliers['Measure_Black or Black British'],
    'y': centraldf_no_outliers['Measure_Emergency caesarean section'],
    'Org_Name': centraldf_no_outliers['Org_Name']
})

p = figure(title="Black or Black British vs. Emergency Caesarean Section",
           x_axis_label='Black or Black British',
           y_axis_label='Emergency Caesarean Section',
           tools="pan,wheel_zoom,box_zoom,reset")

p.circle('x', 'y', size=10, source=source, color="navy", alpha=0.5)

hover = HoverTool()
hover.tooltips = [("Org_Name", "@Org_Name"),
                  ("Black or Black British", "@x"),
                  ("Emergency Caesarean Section", "@y")]

p.add_tools(hover)

x = centraldf_no_outliers['Measure_Black or Black British']
y = centraldf_no_outliers['Measure_Emergency caesarean section']

# (y = mx + c)
p_coeff = np.polyfit(x, y, 1)
y_fit = np.polyval(p_coeff, x)

p.line(x, y_fit, color="red", line_width=2, legend_label="Trend Line")

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="fe678e82-7c6b-4779-b564-6b8e1c6b66ce">Loading BokehJS ...</span>
#     </div>
#   <div id="abd26db1-5149-41b2-82c6-9a730f228750" data-root-id="p1646" style="display: contents;"></div>

# %%
top_10_emergency_c_section = centraldf_no_outliers.sort_values(by='Measure_Emergency caesarean section', ascending=False).head(10)

top_10_emergency_c_section = top_10_emergency_c_section[['Org_Name', 'Measure_Emergency caesarean section']]
top_10_emergency_c_section.rename(columns={'Measure_Emergency caesarean section': '% of Births - Emergency C section'}, inplace=True)
top_10_emergency_c_section.rename(columns={'Org_name': 'NHS Trust'}, inplace=True)

top_10_emergency_c_section
# Out:
#                                               Org_Name  \
# 62              NORTH WEST ANGLIA NHS FOUNDATION TRUST
# 52                         MEDWAY NHS FOUNDATION TRUST
# 20   DONCASTER AND BASSETLAW TEACHING HOSPITALS NHS...
# 33        GREAT WESTERN HOSPITALS NHS FOUNDATION TRUST
# 63              NORTHAMPTON GENERAL HOSPITAL NHS TRUST
# 66           NOTTINGHAM UNIVERSITY HOSPITALS NHS TRUST
# 112   UNIVERSITY HOSPITALS OF NORTH MIDLANDS NHS TRUST
# 116  WARRINGTON AND HALTON TEACHING HOSPITALS NHS F...
# 123                               WYE VALLEY NHS TRUST
# 89                      STOCKPORT NHS FOUNDATION TRUST
#
#      % of Births - Emergency C section
# 62                               33.33
# 52                               32.86
# 20                               31.15
# 33                               29.63
# 63                               28.12
# 66                               27.78
# 112                              27.63
# 116                              27.50
# 123                              27.27
# 89                               26.67

# %%
bottom_10_emergency_c_section = centraldf_no_outliers.sort_values(by='Measure_Emergency caesarean section', ascending=True).head(10)

bottom_10_emergency_c_section = bottom_10_emergency_c_section[['Org_Name', 'Measure_Emergency caesarean section']]
bottom_10_emergency_c_section
# Out:
#                                               Org_Name  \
# 83   SOUTH TYNESIDE AND SUNDERLAND NHS FOUNDATION T...
# 36         HARROGATE AND DISTRICT NHS FOUNDATION TRUST
# 80      SHERWOOD FOREST HOSPITALS NHS FOUNDATION TRUST
# 54         MID CHESHIRE HOSPITALS NHS FOUNDATION TRUST
# 35            HAMPSHIRE HOSPITALS NHS FOUNDATION TRUST
# 118                  WEST SUFFOLK NHS FOUNDATION TRUST
# 84   SOUTH WARWICKSHIRE UNIVERSITY NHS FOUNDATION T...
# 61      NORTH TEES AND HARTLEPOOL NHS FOUNDATION TRUST
# 65         NORTHUMBRIA HEALTHCARE NHS FOUNDATION TRUST
# 121           WORCESTERSHIRE ACUTE HOSPITALS NHS TRUST
#
#      Measure_Emergency caesarean section
# 83                                 12.73
# 36                                 14.29
# 80                                 14.81
# 54                                 14.89
# 35                                 15.07
# 118                                15.15
# 84                                 15.69
# 61                                 16.67
# 65                                 16.98
# 121                                17.14

# %%
output_notebook()

centraldf_no_outliers['Inverted Deprivation'] = pd.to_numeric(centraldf_no_outliers['Inverted Deprivation'], errors='coerce')
centraldf_no_outliers['% of Births - Emergency C section'] = pd.to_numeric(centraldf_no_outliers['Measure_Emergency caesarean section'], errors='coerce')

centraldf_no_outliers = centraldf_no_outliers.dropna(subset=['Inverted Deprivation', '% of Births - Emergency C section'])

source = ColumnDataSource(data={
    'x': centraldf_no_outliers['Inverted Deprivation'],
    'y': centraldf_no_outliers['% of Births - Emergency C section'],
    'Org_Name': centraldf_no_outliers['Org_Name']
})

p = figure(title="Inverted Deprivation vs. % of Births - Emergency C section",
           x_axis_label='Inverted Deprivation',
           y_axis_label='% of Births - Emergency C section',
           tools="pan,wheel_zoom,box_zoom,reset")

# Add a scatter renderer with circle markers
p.circle('x', 'y', size=10, source=source, color="navy", alpha=0.5)

# Add tooltips
hover = HoverTool()
hover.tooltips = [("Org_Name", "@Org_Name"),
                  ("Inverted Deprivation", "@x"),
                  ("% of Births - Emergency C section", "@y")]

p.add_tools(hover)

x = centraldf_no_outliers['Inverted Deprivation']
y = centraldf_no_outliers['% of Births - Emergency C section']

p_coeff = np.polyfit(x, y, 1)
y_fit = np.polyval(p_coeff, x)

p.line(x, y_fit, color="red", line_width=2, legend_label="Trend Line")
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a14852da-a5b8-46b2-8393-e8891fece5fc">Loading BokehJS ...</span>
#     </div>
#   <div id="c861df0e-ecb9-4c85-8361-5e4f7e0d1ccb" data-root-id="p1705" style="display: contents;"></div>
